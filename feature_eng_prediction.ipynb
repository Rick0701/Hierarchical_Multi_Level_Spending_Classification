# %% [markdown]
# # Features Engineering and Prediction

# %%
import re
import pandas as pd
import nltk
from collections import Counter
import numpy as np
import scipy as sp
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import gensim.downloader
# from scipy.stats import chi2_contingency
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report
# from googletrans import Translator
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
import nltk
from nltk.stem import WordNetLemmatizer

# %%
# %pip install watermark

# %%
# %load_ext watermark

# %%
# %watermark -iv
# Out:
# numpy     : 1.22.3
# re        : 2.2.1
# pandas    : 1.4.2
# gensim    : 4.1.2
# scipy     : 1.7.3
# matplotlib: 3.5.1
# nltk      : 3.7

# %%
# %pip freeze > requirements2.txt

# %% [markdown]
# ## Useful Functions

# %% [markdown]
# ### Reading

# %%
MIN_DF = 50
RANDOM_STATE = 42


def read_data(path, deli):
    df = pd.read_csv(path, delimiter=deli)
    return df


def sample_data(df, fraction):
    stratified_sample = df.groupby('puor_ds_level1_new',group_keys=False).apply(lambda x: x.sample(frac=fraction, random_state=RANDOM_STATE))
    return stratified_sample

def filtering_level1(df):
    df = df.loc[df["puor_ds_level1_new"] != "OUT OF SCOPE"]
    return df


def drop_na_records(df):
    # how='any' if at least one element is null in the row, drop the entire row
    return df.dropna(how="any", axis=0)

def clean(text):
    text = text.lower()
    return text

#translator = Translator()
#def translate2en(tokens):
#        translated_tokens = [translator.translate(t, src="auto", dest="en").text for t in tokens]
#        return translated_tokens

# %% [markdown]
# ### Features

# %%
def sklearn_split(text):
    # return re.findall(r'(?u)\b\w\w+\b', text) # matches scikit-learn's TfidfVectorizer class to tokenize text
    # return re.findall(r'(?u)\b[a-zA-Z]\w+\b', text) # starting with a letter
    # return re.findall(r'(?u)[A-Za-z0-9][A-Za-z]+', text)
    return re.findall(r"(?u)[A-Za-z0-9][A-Za-z][A-Za-z]+", text)
    # (?u) turns on Unicode matching and not only ASCII characters
    # \b means starting and ending --> Matches only words, not punctuation

#nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

# stemmatization
ps = PorterStemmer()
vocabulary = {}

# lemmatization qith Wordnet
#nltk.download('wordnet')
#nltk.download('omw-1.4')
lemmatizer = WordNetLemmatizer()


def text_processing(word_tokens, train=True, bigrams=False, range_grams=None, root_word_type='stemmatization'):
    """Generates tokens, implements stemmatization or lemmatization, revomes stopwords and updates the vocabulary
    Args
        word_tokens::string, words to be tokenized
        train::boolean,  if True (default) updates the vocabulary only for the training set. This is done to prevent data leakage
        bigrams::boolean, if False (default) generates unigrams, if True generates bigrams
        range_grams::string, if "(1,2)" generates unigrams and bigrams, if "(2,2)" gemerates only bigrams, but
                                words with only onegram are retained
                                e.g. transportation cost for UK --> [transport cost, cost UK]
                                e.g. 1213 transport --> [transport]
    Return
        text_proc_ret::list, list of word tokens
        
    """
    if root_word_type=='stemmatization':
        text_proc = [ps.stem(w) for w in word_tokens if not w in stop_words]
    elif root_word_type=='lemmatization':
        text_proc = [lemmatizer.lemmatize(word, pos="v") for word in word_tokens]  

    if bigrams == True and range_grams == "(1,2)":
        text_proc_ret = text_proc + [
            f"{text_proc[i]} {text_proc[i+1]}" for i in range(len(text_proc) - 1)
        ]

    if bigrams == True and range_grams == "(2,2)":
        if len(text_proc) == 1:
            text_proc_ret = text_proc.copy()
        else:
            text_proc_ret = [f"{text_proc[i]} {text_proc[i+1]}" for i in range(len(text_proc) - 1)]

    if train:
        for w in text_proc_ret:
            if w in vocabulary:
                vocabulary[w] += 1
            else:
                vocabulary[w] = 1
    return text_proc_ret


def encoding_categorical_features(X_train, X_test, min_frq, drp="first", handle_uknwn="ignore"):
    """One hot encoding
    Args:
        X_train::vector or pandas Series, the X feature of the training set to be encoded
        X_test::vector or pandas Series, the X feature the test test to be encoded
        min_frq::int, minminum frequency for a value of the category to be retained
        drp::string, drop first value because it can be inferred from the others
        handle_uknw::string, ignore new values when are encountered i.e. in the test set
    Return
        encodings::tuple, containing the encoding of the training set and test, and a mapping of categories for the training set
    """
    enc = OneHotEncoder(drop=drp, handle_unknown=handle_uknwn, min_frequency=min_frq)
    X_train_enc = enc.fit_transform(X_train)
    cats = enc.categories_[0]
    map_id_to_cat = {v: k for v, k in enumerate(cats)}
    print(f"Number of features:{len(cats)}")
    print(f"First five features:{cats[:5]}")

    if min_frq != None:
        cats_infrequent = enc.infrequent_categories_[0]
        cats_infrequent_set = set(cats_infrequent)
        cats_retained = [c for c in cats if c not in cats_infrequent_set]
        print(f"Infrequent categories: {len(cats_infrequent)}")
        print(f"First five entries: {cats_infrequent[:5]}")
        print(
            f"Retained features (# Features - Infrequent features): {len(cats)-len(enc.infrequent_categories_[0])}"
        )
        map_id_to_cat = {v: k for v, k in enumerate(cats_retained)}

    X_test_enc = enc.transform(X_test)
    encodings = (X_train_enc, X_test_enc, map_id_to_cat)
    return encodings

# Functions for Word2Vec
# Loading pre-trained embeddings from Google
# google_news = gensim.downloader.load('word2vec-google-news-300')

def remove_stop_word_to_tokens(row):
    return [w for w in row if w not in stop_words]


def remove_words_not_in_embeddings(row, embds):
    return [w for w in row if w in embds.keys()]


def generate_word_vector_features(tokenized_texts, embds):
    docs = []
    for tokens in tokenized_texts:
        embeddings_row = []
        for word in tokens:
            if len(tokens)==0:
                embeddings_row.append(np.zeros(300))
            embeddings_row.append(embds[word])
            matrix_row = np.sum(np.vstack(embeddings_row), axis=0)
        docs.append(matrix_row)
    return np.vstack(docs)

# %% [markdown]
# ### Modeling

# %%
def model(classifier, X_tr, y_tr, X_ts, y_ts, rnd_state=RANDOM_STATE, cls_wght=None, max_feat=None, 
          random_forest=False, gradient_boosting=False, n_ests=0, lr=0):
    """fitting a machine learning model, provides accuracies at the class level and predicts values for the test set
    Args
        classifier, type of classifier e.g. DecisionTreeClassifier
        X_tr, training set
        y_tr, target variable of training set i.e. level1, or level2, or level3 or level4 category
        X_ts, test set
        y_ts, target variable of test set
        rnd_state::int, random state to have reproducible results
        cls_wght::dict or string, class weights to balance the model e.g. balanced
    Return
        modeling::tuple, cotaining the model, the prediction, and the ground-truth values


    """
    if gradient_boosting:
        mdl = classifier(random_state=rnd_state, n_estimators=n_ests, learning_rate=lr)   
    elif random_forest:
        mdl = classifier(random_state=rnd_state, class_weight=cls_wght, max_features=max_feat, n_estimators=n_ests) 
    else: # Decision Tree
        mdl = classifier(random_state=rnd_state, class_weight=cls_wght, max_features=max_feat)
    mdl.fit(X_tr, y_tr)
    print("Accuracy on training set: {:.3f}".format(mdl.score(X_tr, y_tr)))
    print("Accuracy on test set: {:.3f}".format(mdl.score(X_ts, y_ts)))
    dummy_cls = DummyClassifier(strategy="stratified").fit(X_tr, y_tr)
    print("Accuracy on test set by a DUMMY CLASSIFIER: {:.3f}".format(dummy_cls.score(X_ts, y_ts)))
    y_preds = mdl.predict(X_ts)  # X_train
    y_trues = y_ts  # train.puor_ds_level1_new #
    print("Classification Report for Test Set")
    print(classification_report(y_true=y_trues, y_pred=y_preds))
    print("Classification Report for Training Set")
    print(classification_report(y_true=y_tr, y_pred=mdl.predict(X_tr)))
    modeling = (mdl, y_preds, y_trues)
    return modeling


def integrating_prev_lev_predict_next_lev(X_train, X_test, level, model):
    """Integrates prediction of level i as a new feature for the next training predicting the level i+1 category
    Args
        X_train,
        X_test,
        level::string, category level e.g. puor_ds_level2_new
        model, classifier
    Return
        train_test_new::tuple

    """
    X_train_next_lvl_pred = model.predict(X_train).reshape(-1, 1)
    X_test_next_lvl = np.array(test[level]).reshape(-1, 1)
    X_train_next_lvl_pred_one, X_test_next_lvl_one, map = encoding_categorical_features(
        X_train=X_train_next_lvl_pred, X_test=X_test_next_lvl, min_frq=None
    )
    X_train_new = sp.sparse.hstack([X_train, X_train_next_lvl_pred_one])
    X_test_new = sp.sparse.hstack([X_test, X_test_next_lvl_one])
    train_test_new = (X_train_new, X_test_new)
    return train_test_new

# %% [markdown]
# ## Reading and exploring data

# %%
train = read_data(
                    path=r"C:\Users\riccardoricci\Documents\data_MADS_CAPSTONE\training_data_2025-03-03.csv",
                  # path="data/training_data_2025-03-03.csv", 
                  # Relative path is not possible for confidentiality reasons
                  deli="|")
train = drop_na_records(train)
train = filtering_level1(train)
print(len(train))
# Out:
# 2074804

# %%
test = read_data(
                #path="data/test_set_2025-03-03.csv",
                path=r"C:\Users\riccardoricci\Documents\data_MADS_CAPSTONE\test_set_2025-03-03.csv",
                deli="|")
test = drop_na_records(test)
test = filtering_level1(test)

# %%
train['puor_ds_level1_new'].value_counts(normalize=True)
# Out:
# SUPPLY CHAIN             0.571922
# TECHNICAL PROCUREMENT    0.247748
# GENERAL PROCUREMENT      0.180330
# Name: puor_ds_level1_new, dtype: float64

# %%
test['puor_ds_level1_new'].value_counts(normalize=True)
# Out:
# GENERAL PROCUREMENT      0.552626
# TECHNICAL PROCUREMENT    0.440668
# SUPPLY CHAIN             0.006707
# Name: puor_ds_level1_new, dtype: float64

# %%
# Reading a sample of training data to make things faster
train = sample_data(train, 0.15)

# %%
len(train)
# Out:
# 311220

# %%
train['puor_ds_level1_new'].value_counts(normalize=True)
# Out:
# SUPPLY CHAIN             0.571923
# TECHNICAL PROCUREMENT    0.247748
# GENERAL PROCUREMENT      0.180329
# Name: puor_ds_level1_new, dtype: float64

# %%
print(f"Training set has {train.shape[0]} rows and {train.shape[1]} columns")
print(f"Test set has {test.shape[0]} rows and {test.shape[1]} columns")
# Out:
# Training set has 311220 rows and 11 columns
# Test set has 61282 rows and 11 columns

# %%
train.sample(5)
# Out:
#                puor_id_order_line puor_id_lfa1_supplier puor_id_t001_company  \
# 2022446   SAPECCFE3_3300024877_20  SAPECCFE3_0000017593       SAPECCFE3_IT35
# 226863    SAPECCFE3_7010088915_10  SAPECCFE3_0000179949       SAPECCFE3_IN10
# 2216726  SAPECCFE3_4570217221_190  SAPECCFE3_0000198510       SAPECCFE3_LU20
# 383998    SAPECCFIP_4500655281_60  SAPECCFIP_0000608196       SAPECCFIP_0001
# 1406070   SAPECCFE3_8808013346_40  SAPECCFE3_0000148331       SAPECCFE3_IE10
#
#         puor_id_prgp_purchasing_group puor_id_pror_purchasing_org  \
# 2022446                 SAPECCFE3_199              SAPECCFE3_ITL6
# 226863                  SAPECCFE3_B06              SAPECCFE3_IN06
# 2216726                 SAPECCFE3_4SN              SAPECCFE3_LU1B
# 383998                  SAPECCFIP_149              SAPECCFIP_1100
# 1406070                 SAPECCFE3_IE0              SAPECCFE3_IE05
#
#         puor_ds_po_description_translated     puor_ds_level1_new  \
# 2022446              Transport 03.01.2023           SUPPLY CHAIN
# 226863            Transport /Ramanathapur           SUPPLY CHAIN
# 2216726                  26786_25.01.2025           SUPPLY CHAIN
# 383998                Dia-Bohrkrone 132mm  TECHNICAL PROCUREMENT
# 1406070                          Delivery  TECHNICAL PROCUREMENT
#
#          puor_ds_level2_new                  puor_ds_level3_new  \
# 2022446  PRIMARY TRANSPORTS                      ROAD TRANSPORT
# 226863   PRIMARY TRANSPORTS                      ROAD TRANSPORT
# 2216726  PRIMARY TRANSPORTS                      ROAD TRANSPORT
# 383998     AUTOMATION & MRO  TECHNICAL MATERIALS, PPE & CLOTHES
# 1406070    AUTOMATION & MRO  TECHNICAL MATERIALS, PPE & CLOTHES
#
#                                         puor_ds_level4_new puor_cd_mat_group
# 2022446                                Road Transportation            ZZ0304
# 226863                                 Road Transportation            ZZ0304
# 2216726  Road Transportation Finished Products Export C...            ZZ1115
# 383998   Other Spare parts (not codified, catalogues it...            ZZ0104
# 1406070  Other Spare parts (not codified, catalogues it...            ZZ0104

# %%
for lvl in range(1,5):
    print(f"TRAIN: # categories at Level {str(lvl)}:",len(train[f"puor_ds_level{str(lvl)}_new"].drop_duplicates()))
    print(f"TEST: # categories at Level {str(lvl)}:",len(test[f"puor_ds_level{str(lvl)}_new"].drop_duplicates()))
# Out:
# TRAIN: # categories at Level 1: 3
# TEST: # categories at Level 1: 3
# TRAIN: # categories at Level 2: 20
# TEST: # categories at Level 2: 19
# TRAIN: # categories at Level 3: 104
# TEST: # categories at Level 3: 85
# TRAIN: # categories at Level 4: 573
# TEST: # categories at Level 4: 426

# %%
train["puor_ds_level1_new"].value_counts()
# Out:
# SUPPLY CHAIN             177994
# TECHNICAL PROCUREMENT     77104
# GENERAL PROCUREMENT       56122
# Name: puor_ds_level1_new, dtype: int64

# %%
test["puor_ds_level1_new"].value_counts()
# Out:
# GENERAL PROCUREMENT      33866
# TECHNICAL PROCUREMENT    27005
# SUPPLY CHAIN               411
# Name: puor_ds_level1_new, dtype: int64

# %% [markdown]
# SUPPLY CHAIN is the most frequent category, but this is the least represented in the test set
#
# **Training and test datasets are not balanced with respect to the categories**.

# %%
train[["puor_ds_level1_new","puor_ds_level2_new"]].value_counts()
# Out:
# puor_ds_level1_new     puor_ds_level2_new
# SUPPLY CHAIN           PRIMARY TRANSPORTS                        134525
# TECHNICAL PROCUREMENT  AUTOMATION & MRO                           66946
# SUPPLY CHAIN           SECONDARY FREIGHT                          34240
# GENERAL PROCUREMENT    SALES SERVICES                             23905
#                        WORKPLACE SERVICES                         12254
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL                 8102
# GENERAL PROCUREMENT    MARKETING SERVICES                          6809
# SUPPLY CHAIN           CUSTOM BROKERAGE & FORWARDING AGENCIES      6014
# GENERAL PROCUREMENT    IT - INFORMATION TECHNOLOGY                 3866
#                        PEOPLE SERVICES                             3803
# SUPPLY CHAIN           WAREHOUSING                                 2887
# GENERAL PROCUREMENT    MOBILITY                                    2603
#                        PROFESSIONAL SERVICES                       2361
# TECHNICAL PROCUREMENT  PROCESS EQUIPMENT                           1913
# GENERAL PROCUREMENT    SURPRISE L2                                  387
# SUPPLY CHAIN           PALLETTS RENT & LEASE                        235
# TECHNICAL PROCUREMENT  ENERGY                                       143
# GENERAL PROCUREMENT    ENERGY AND UTILITIES FOR OFFICES              99
# SUPPLY CHAIN           PALLETTS PURCHASING                           93
# GENERAL PROCUREMENT    OTHER NON GP                                  35
# dtype: int64

# %%
test[["puor_ds_level1_new","puor_ds_level2_new"]].value_counts()
# Out:
# puor_ds_level1_new     puor_ds_level2_new
# GENERAL PROCUREMENT    MARKETING SERVICES                        14748
# TECHNICAL PROCUREMENT  AUTOMATION & MRO                          13038
# GENERAL PROCUREMENT    WORKPLACE SERVICES                        10223
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL                9292
#                        PROCESS EQUIPMENT                          4530
# GENERAL PROCUREMENT    PEOPLE SERVICES                            4039
#                        SALES SERVICES                             2740
#                        MOBILITY                                   1439
#                        PROFESSIONAL SERVICES                       415
#                        IT - INFORMATION TECHNOLOGY                 246
# TECHNICAL PROCUREMENT  ENERGY                                      145
# SUPPLY CHAIN           CUSTOM BROKERAGE & FORWARDING AGENCIES      117
#                        PRIMARY TRANSPORTS                           87
#                        WAREHOUSING                                  71
#                        SECONDARY FREIGHT                            59
#                        PALLETTS RENT & LEASE                        54
#                        PALLETTS PURCHASING                          23
# GENERAL PROCUREMENT    ENERGY AND UTILITIES FOR OFFICES             15
#                        SURPRISE L2                                   1
# dtype: int64

# %%
train[["puor_ds_level1_new","puor_ds_level2_new","puor_ds_level3_new"]].value_counts().head(10)
# Out:
# puor_ds_level1_new     puor_ds_level2_new                      puor_ds_level3_new
# SUPPLY CHAIN           PRIMARY TRANSPORTS                      ROAD TRANSPORT                                               130765
# TECHNICAL PROCUREMENT  AUTOMATION & MRO                        TECHNICAL MATERIALS, PPE & CLOTHES                            57346
# SUPPLY CHAIN           SECONDARY FREIGHT                       DISTRIBUTION                                                  34240
# GENERAL PROCUREMENT    SALES SERVICES                          POS MATERIAL                                                  18632
# TECHNICAL PROCUREMENT  AUTOMATION & MRO                        MAINTENANCE SERVICES                                           9119
# GENERAL PROCUREMENT    WORKPLACE SERVICES                      OFFICE SUPPLIES AND SERVICES                                   7698
# SUPPLY CHAIN           CUSTOM BROKERAGE & FORWARDING AGENCIES  FREIGHT FORWARDING AGENCIES                                    6014
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL             LABORATORY EQUIPMENT AND SERVICES                              3745
# SUPPLY CHAIN           PRIMARY TRANSPORTS                      SEA TRANSPORT                                                  2382
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL             FACILITY MANAGEMENT SOFTSERVICES FOR INDUSTRIAL LOCATIONS      2266
# dtype: int64

# %%
test[["puor_ds_level1_new","puor_ds_level2_new","puor_ds_level3_new"]].value_counts().head(10)
# Out:
# puor_ds_level1_new     puor_ds_level2_new           puor_ds_level3_new
# GENERAL PROCUREMENT    MARKETING SERVICES           CREATIVE DESIGN                                              10975
# TECHNICAL PROCUREMENT  AUTOMATION & MRO             TECHNICAL MATERIALS, PPE & CLOTHES                            8932
# GENERAL PROCUREMENT    WORKPLACE SERVICES           OFFICE SUPPLIES AND SERVICES                                  6884
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL  FACILITY MANAGEMENT SOFTSERVICES FOR INDUSTRIAL LOCATIONS     3290
# GENERAL PROCUREMENT    PEOPLE SERVICES              TRAINING                                                      2524
# TECHNICAL PROCUREMENT  INFRASTRUCTURE & INDUSTRIAL  LABORATORY EQUIPMENT AND SERVICES                             2321
#                        AUTOMATION & MRO             INDUSTRIAL AUTOMATION AND ROBOTICS                            2192
#                                                     MAINTENANCE SERVICES                                          1914
#                        INFRASTRUCTURE & INDUSTRIAL  FACILITY MANAGEMENT HARDSERVICES FOR INDUSTRIAL LOCATIONS     1901
# GENERAL PROCUREMENT    WORKPLACE SERVICES           CLEANING                                                      1876
# dtype: int64

# %%
train[["puor_ds_level1_new","puor_ds_level2_new","puor_ds_level3_new","puor_ds_level4_new"]].value_counts().head(10)
# Out:
# puor_ds_level1_new     puor_ds_level2_new  puor_ds_level3_new                  puor_ds_level4_new
# SUPPLY CHAIN           PRIMARY TRANSPORTS  ROAD TRANSPORT                      Road Transportation                                            104026
#                        SECONDARY FREIGHT   DISTRIBUTION                        Distribution to Customers and Returned Goods from Customers     34208
# GENERAL PROCUREMENT    SALES SERVICES      POS MATERIAL                        POS materials Storage and Logistic                              12574
# SUPPLY CHAIN           PRIMARY TRANSPORTS  ROAD TRANSPORT                      Road Transportation Finished Products Export Costs               9408
# TECHNICAL PROCUREMENT  AUTOMATION & MRO    MAINTENANCE SERVICES                OPX - Ordinary Maintenance                                       8929
#                                            TECHNICAL MATERIALS, PPE & CLOTHES  Other Materials Immediate Use for Maintenance Plant              7071
#                                                                                Other Spare parts (not codified, catalogues items)               5173
# GENERAL PROCUREMENT    WORKPLACE SERVICES  OFFICE SUPPLIES AND SERVICES        Office supplies                                                  4458
# TECHNICAL PROCUREMENT  AUTOMATION & MRO    TECHNICAL MATERIALS, PPE & CLOTHES  ELECTRICAL / ELECTRONICAL COMPONENTS                             4116
# SUPPLY CHAIN           PRIMARY TRANSPORTS  ROAD TRANSPORT                      Extra Cost  Transpor Finished product                            4016
# dtype: int64

# %%
test[["puor_ds_level1_new","puor_ds_level2_new","puor_ds_level3_new","puor_ds_level4_new"]].value_counts().head(10)
# Out:
# puor_ds_level1_new     puor_ds_level2_new           puor_ds_level3_new                                         puor_ds_level4_new
# GENERAL PROCUREMENT    MARKETING SERVICES           CREATIVE DESIGN                                            Packaging & POS - Creative Concept                              7186
#                        WORKPLACE SERVICES           OFFICE SUPPLIES AND SERVICES                               Office supplies                                                 4053
# TECHNICAL PROCUREMENT  AUTOMATION & MRO             TECHNICAL MATERIALS, PPE & CLOTHES                         Other Spare parts (not codified, catalogues items)              2958
# GENERAL PROCUREMENT    PEOPLE SERVICES              TRAINING                                                   Training Design & Cost of Personal                              2524
#                        MARKETING SERVICES           CREATIVE DESIGN                                            Packaging & POS - Mockups / Samples                             2041
#                        WORKPLACE SERVICES           OFFICE SUPPLIES AND SERVICES                               Other Consumables, Material and Small Supplies                  2035
#                                                     CLEANING                                                   Cleaning, Waste,Pest Services and Material for No Industrial    1876
# TECHNICAL PROCUREMENT  AUTOMATION & MRO             TECHNICAL MATERIALS, PPE & CLOTHES                         Other Materials Immediate Use for Maintenance Plant             1691
#                        INFRASTRUCTURE & INDUSTRIAL  FACILITY MANAGEMENT SOFTSERVICES FOR INDUSTRIAL LOCATIONS  Cleaning Consultancy and Services                               1648
#                                                     LABORATORY EQUIPMENT AND SERVICES                          Consumable                                                      1559
# dtype: int64

# %% [markdown]
# ### Exploring Features

# %%
train["puor_ds_po_description_translated"].sample(5)
# Out:
# 205852                  Transport /Tula
# 2337185           Materials - Packaging
# 872981                  Plastic Pallets
# 767951     Transport Guarulhos/SAOPAULO
# 319082                      Transport /
# Name: puor_ds_po_description_translated, dtype: object

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### PO Text

# %% [markdown]
# TF-IDF Weighting

# %%
# stemmatization
train["puor_ds_po_description_translated_token_sklearn_stem"] = (
    train["puor_ds_po_description_translated"]
    .apply(clean)
    .apply(sklearn_split)
    .apply(text_processing, bigrams=True, range_grams="(1,2)", root_word_type='stemmatization')
)

test["puor_ds_po_description_translated_token_sklearn_stem"] = (
    test["puor_ds_po_description_translated"]
    .apply(clean)
    .apply(sklearn_split)
    .apply(text_processing, train=False, bigrams=True, range_grams="(1,2)", root_word_type='stemmatization')
)

# %%
# lemmatization
# train["puor_ds_po_description_translated_token_sklearn_lem"] = (
#     train["puor_ds_po_description_translated"]
#     .apply(clean)
#     .apply(sklearn_split)
#     .apply(text_processing, bigrams=True, range_grams="(1,2)", root_word_type='lemmatization')
# )
# 
# test["puor_ds_po_description_translated_token_sklearn_lem"] = (
#     test["puor_ds_po_description_translated"]
#     .apply(clean)
#     .apply(sklearn_split)
#     .apply(text_processing, train=False, bigrams=True, range_grams="(1,2)", root_word_type='lemmatization')
# )

# %% [markdown]
# Word2Vec

# %%
# train['puor_ds_po_description_translated_tokens_w2v'] = train["puor_ds_po_description_translated"]\
#     .apply(clean)\
#     .apply(sklearn_split)
# test['puor_ds_po_description_translated_tokens_w2v'] = test["puor_ds_po_description_translated"]\
#     .apply(clean)\
#     .apply(sklearn_split)
# 
# vocabulary_no_stem = list(pd.Series(np.hstack(train['puor_ds_po_description_translated_tokens_w2v'].values)).drop_duplicates().values)
# 
# # word_index = {w:i for i,w in enumerate(vocabulary_no_stem)}
# 
# embeddings = {word: google_news[word] for word in vocabulary_no_stem if word in google_news}

# %%
# train['puor_ds_po_description_translated_tokens_clean_w2v'] = train['puor_ds_po_description_translated_tokens_w2v']\
#                         .apply(remove_stop_word_to_tokens)\
#                         .apply(remove_words_not_in_embeddings, embds=embeddings)
# 
# test['puor_ds_po_description_translated_tokens_clean_w2v'] = test['puor_ds_po_description_translated_tokens_w2v']\
#                         .apply(remove_stop_word_to_tokens)\
#                         .apply(remove_words_not_in_embeddings, embds=embeddings)

# X_train_word2vec = generate_word_vector_features(train['puor_ds_po_description_translated_tokens_clean_w2v'], embeddings)
# X_test_word2vec = generate_word_vector_features(test['puor_ds_po_description_translated_tokens_clean_w2v'], embeddings)

# %%
train[
    [
        "puor_ds_level1_new",
        "puor_ds_po_description_translated",
        "puor_ds_po_description_translated_token_sklearn_stem",
#        "puor_ds_po_description_translated_token_sklearn_lem",
#        "puor_ds_po_description_translated_tokens_clean_w2v",
    ]
].sample(10)
# Out:
#             puor_ds_level1_new         puor_ds_po_description_translated  \
# 718832            SUPPLY CHAIN                         INSURANCE 11 2022
# 232934     GENERAL PROCUREMENT             FMC CHRISTMAS MARKET ASSEMBLY
# 327523            SUPPLY CHAIN                    Transport São Josédos/
# 1605824  TECHNICAL PROCUREMENT  Contr.Nett.extr.CARAGLIO:Off.88 f.184.23
# 2166689  TECHNICAL PROCUREMENT     Women's bathroom 20x10 (Trocivel 1mm)
# 2365708           SUPPLY CHAIN                  Transportation /CampoBom
# 2400506           SUPPLY CHAIN                      Transport /Guarulhos
# 1609725  TECHNICAL PROCUREMENT  Contrat Mission Caraglio :OF.61 F.562.23
# 195936   TECHNICAL PROCUREMENT                 40NB BSP 316 SCREW UNIONS
# 888349            SUPPLY CHAIN                     Transports 28.08.2024
#
#         puor_ds_po_description_translated_token_sklearn_stem
# 718832                                             [insur]
# 232934   [fmc, christma, market, assembl, fmc christma,...
# 327523            [transport, jo, do, transport jo, jo do]
# 1605824  [contr, nett, extr, caraglio, contr nett, nett...
# 2166689  [women, bathroom, trocivel, 1mm, women bathroo...
# 2365708          [transport, campobom, transport campobom]
# 2400506          [transport, guarulho, transport guarulho]
# 1609725  [contrat, mission, caraglio, contrat mission, ...
# 195936   [0nb, bsp, screw, union, 0nb bsp, bsp screw, s...
# 888349                                         [transport]

# %%
# train.loc[train["puor_id_order_line"]=='SAPECCFE3_1601004205_50']

# %%
train["n_tokens_stem"] = train["puor_ds_po_description_translated_token_sklearn_stem"].apply(lambda x: len(x))
# train["n_tokens_lem"] = train["puor_ds_po_description_translated_token_sklearn_stem"].apply(lambda x: len(x))
# train["n_tokens_w2v"] = train["puor_ds_po_description_translated_tokens_clean_w2v"].apply(lambda x: len(x))

print(f"Average number of tokens per record: {np.mean(train.n_tokens_stem)}")
# print(f"Average number of tokens per record: {np.mean(train.n_tokens_lem)}")
# print(f"Average number of tokens per record (Word2Vec): {np.mean(train.n_tokens_w2v)}")
# Out:
# Average number of tokens per record: 3.6038911381016643

# %% [markdown]
# Some text cannot be encoded because are just dates or codes

# %%
train[train["n_tokens_stem"] == 0][
    [
        "puor_ds_level4_new",
        "puor_ds_po_description_translated",
        "puor_ds_po_description_translated_token_sklearn_stem",
    ]
]
# Out:
#                                    puor_ds_level4_new  \
# 936389    Function related / professional consultancy
# 1958633                          BUILDING MAINTENANCE
# 186928                         Employees tax services
# 2515962  Design & Management of non Digital Promotion
# 2686538  Design & Management of non Digital Promotion
# ...                                               ...
# 1622964                    OPX - Ordinary Maintenance
# 917771                     OPX - Ordinary Maintenance
# 119963           ELECTRICAL / ELECTRONICAL COMPONENTS
# 975596                    SPECIFIC DRAWING COMPONENTS
# 1944683                    OPX - Ordinary Maintenance
#
#                puor_ds_po_description_translated  \
# 936389   IT02I2B2412610 you 27 09 2024 cc 205965
# 1958633                                     DC26
# 186928                                    565220
# 2515962                                 73510030
# 2686538                                 73510030
# ...                                          ...
# 1622964                                  Гири M1
# 917771                             ab 01.01.2022
# 119963                  64723460501 Рамка дверцы
# 975596                          LA31535D-0000-01
# 1944683                                DS3678-SR
#
#         puor_ds_po_description_translated_token_sklearn_stem
# 936389                                                  []
# 1958633                                                 []
# 186928                                                  []
# 2515962                                                 []
# 2686538                                                 []
# ...                                                    ...
# 1622964                                                 []
# 917771                                                  []
# 119963                                                  []
# 975596                                                  []
# 1944683                                                 []
#
# [20115 rows x 3 columns]

# %%
print(f"Percentage of records that have no tokens: {len(train[train.n_tokens_stem == 0]) / len(train):.2%}")
# Out:
# Percentage of records that have no tokens: 6.46%

# %%
# train_expl = train[train_expl["n_tokens"]>0]
# train_expl.shape

# %%
vocabulary_min_df = {w: k for w, k in vocabulary.items() if k >= MIN_DF}
print(f"Length vocabulary: {len(vocabulary)}")
print(f"Length vocabulary with word frequency greater than {MIN_DF}: {len(vocabulary_min_df)}")
# Out:
# Length vocabulary: 200762
# Length vocabulary with word frequency greater than 50: 2228

# %%
# https://www.davidsbatista.net/blog/2018/02/28/TfidfVectorizer/


def dummy_fun(doc):
    return doc


vectorizer = TfidfVectorizer(
    analyzer="word",
    tokenizer=dummy_fun,
    preprocessor=dummy_fun,
    token_pattern=None,
    vocabulary=vocabulary_min_df.keys(),
)

# %% [markdown]
# With Lemmatization

# %%
# X_train_text_proc_lem = vectorizer.fit_transform(
#     train["puor_ds_po_description_translated_token_sklearn_lem"]
# )
# X_test_text_proc_lem = vectorizer.transform(test["puor_ds_po_description_translated_token_sklearn_lem"])

# cats_map_text_lem = {v: k for v, k in enumerate(vectorizer.get_feature_names_out())}
# len(cats_map_text_lem)

# %%
# X_train_text_proc_lem.shape

# %%
# X_test_text_proc_lem.shape

# %% [markdown]
# With Stemmatization

# %%
X_train_text_proc_stem = vectorizer.fit_transform(
    train["puor_ds_po_description_translated_token_sklearn_stem"]
)
X_test_text_proc_stem = vectorizer.transform(test["puor_ds_po_description_translated_token_sklearn_stem"])

# %%
cats_map_text = {v: k for v, k in enumerate(vectorizer.get_feature_names_out())}
len(cats_map_text)
# Out:
# 2228

# %%
# pd.crosstab(train.puor_id_lfa1_supplier, train.puor_ds_level1_new)
# chi2_contingency(pd.crosstab(train_expl.puor_id_lfa1_supplier, train_expl.puor_ds_level2_new))

# %%
# Exporting data for data viz
train.to_csv(r'C:\Users\riccardoricci\Documents\data_MADS_CAPSTONE\train_features.csv')
test.to_csv(r'C:\Users\riccardoricci\Documents\data_MADS_CAPSTONE\test_features.csv')

# %% [markdown]
# #### Latent Semantic Indexing
#
# Using Singular Value Decomposition

# %%
X_train_text_proc_stem.shape
# Out:
# (311220, 2228)

# %%
#n_components = 500  # Choose number of singular values/vectors to keep
#svd = TruncatedSVD(n_components=n_components)
#X_train_text_proc_reduced = svd.fit_transform(X_train_text_proc_stem) 

#print("Reduced matrix shape:", X_train_text_proc_reduced.shape)
#cumulative_variance = np.cumsum(svd.explained_variance_ratio_)

# %% [markdown]
# Scree plot

# %%
#plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
#plt.axhline(y=0.80, color='r', linestyle='--', label="80% variance")
#plt.xlabel("Number of Components")
#plt.ylabel("Cumulative Explained Variance")
#plt.title("Scree Plot")
#plt.legend()
#plt.show()

# %%
#X_test_text_proc_reduced = svd.transform(X_test_text_proc_stem)

# %% [markdown]
# ### Supplier

# %%
X_train_suppl = np.array(train.puor_id_lfa1_supplier).reshape(-1, 1)
X_test_suppl = np.array(test.puor_id_lfa1_supplier).reshape(-1, 1)
X_train_suppl_one, X_test_suppl_one, cats_map_suppl = encoding_categorical_features(
    X_train=X_train_suppl, X_test=X_test_suppl, min_frq=10
)
# Out:
# Number of features:14649
# First five features:['SAPECCFE3_0000010001' 'SAPECCFE3_0000010007' 'SAPECCFE3_0000010009'
#  'SAPECCFE3_0000010011' 'SAPECCFE3_0000010018']
# Infrequent categories: 11920
# First five entries: ['SAPECCFE3_0000010009' 'SAPECCFE3_0000010011' 'SAPECCFE3_0000010018'
#  'SAPECCFE3_0000010020' 'SAPECCFE3_0000010045']
# Retained features (# Features - Infrequent features): 2729
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:182: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train_suppl_one.shape
# Out:
# (311220, 2729)

# %%
X_test_suppl_one.shape
# Out:
# (61282, 2729)

# %% [markdown]
# ### Purchasing Organization

# %%
X_train_porg = np.array(train.puor_id_pror_purchasing_org).reshape(-1, 1)
X_test_porg = np.array(test.puor_id_pror_purchasing_org).reshape(-1, 1)
X_train_porg_one, X_test_porg_one, cats_map_porg = encoding_categorical_features(
    X_train=X_train_porg, X_test=X_test_porg, min_frq=10
)
# Out:
# Number of features:407
# First five features:['SAPECCFE3_2A09' 'SAPECCFE3_2A10' 'SAPECCFE3_AE09' 'SAPECCFE3_AE29'
#  'SAPECCFE3_AE33']
# Infrequent categories: 89
# First five entries: ['SAPECCFE3_AE09' 'SAPECCFE3_AE29' 'SAPECCFE3_AE38' 'SAPECCFE3_AE40'
#  'SAPECCFE3_AR08']
# Retained features (# Features - Infrequent features): 318
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:182: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train_porg_one.shape
# Out:
# (311220, 318)

# %%
X_test_porg_one.shape
# Out:
# (61282, 318)

# %% [markdown]
# ### Company

# %%
X_train_comp = np.array(train.puor_id_t001_company).reshape(-1, 1)
X_test_comp = np.array(test.puor_id_t001_company).reshape(-1, 1)
X_train_comp_one, X_test_comp_one, cats_map_comp = encoding_categorical_features(
    X_train=X_train_comp, X_test=X_test_comp, min_frq=20
)
# Out:
# Number of features:90
# First five features:['SAPECCFE3_10ES' 'SAPECCFE3_10RO' 'SAPECCFE3_10SE' 'SAPECCFE3_11CN'
#  'SAPECCFE3_11SE']
# Infrequent categories: 7
# First five entries: ['SAPECCFE3_AE10' 'SAPECCFE3_AE20' 'SAPECCFE3_BE30' 'SAPECCFE3_LU35'
#  'SAPECCFE3_VN30']
# Retained features (# Features - Infrequent features): 83

# %% [markdown]
# ### Purchasing Group

# %%
X_train_pgrp = np.array(train.puor_id_prgp_purchasing_group).reshape(-1, 1)
X_test_pgrp = np.array(test.puor_id_prgp_purchasing_group).reshape(-1, 1)
X_train_pgrp_one, X_test_pgrp_one, cats_map_prgp = encoding_categorical_features(
    X_train=X_train_pgrp, X_test=X_test_pgrp, min_frq=10
)
# Out:
# Number of features:1272
# First five features:['SAPECCFE3_000' 'SAPECCFE3_004' 'SAPECCFE3_100' 'SAPECCFE3_101'
#  'SAPECCFE3_103']
# Infrequent categories: 574
# First five entries: ['SAPECCFE3_000' 'SAPECCFE3_004' 'SAPECCFE3_100' 'SAPECCFE3_101'
#  'SAPECCFE3_10C']
# Retained features (# Features - Infrequent features): 698
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_encoders.py:182: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
y_train = train.puor_ds_level1_new
y_test = test.puor_ds_level1_new

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Predicting Level 1

# %% [markdown]
# Let's use just text features to compare tf-idf and word2vec

# %% [markdown]
# TF-IDF only

# %%
#print("TF-IDF (Lemmatization)")
#tree, y_predictions, y_gold_labels = model(
#    DecisionTreeClassifier, X_tr=X_train_text_proc_lem, y_tr=y_train, X_ts=X_test_text_proc_lem, y_ts=y_test, cls_wght='balanced'
#)

# %%
#print("TF-IDF (Stemmatization)")
## weights = {"SUPPLY CHAIN": 0.43, "TECHNICAL PROCUREMENT": 0.75, "GENERAL PROCUREMENT": 0.82}
#tree, y_predictions, y_gold_labels = model(
#    DecisionTreeClassifier, X_tr=X_train_text_proc_stem, y_tr=y_train, X_ts=X_test_text_proc_stem, y_ts=y_test, cls_wght='balanced'
#)

# %% [markdown]
# TF-IDF (Stemmatization) with Latent Semantic Analysis

# %%
#print(f"TF-IDF (Stemmatization) with Latent Semantic Analysis (Number of components retained: {len(svd.components_)})")
#tree, y_predictions, y_gold_labels = model(
#    DecisionTreeClassifier, X_tr=X_train_text_proc_reduced, y_tr=y_train, X_ts=X_test_text_proc_reduced, y_ts=y_test, cls_wght='balanced'
#)

# %% [markdown]
# Using Word2Vec

# %%
# print("Word2Vec")
#tree, y_predictions, y_gold_labels = model(
#    DecisionTreeClassifier, X_tr=X_train_word2vec, y_tr=y_train, X_ts=X_test_word2vec, y_ts=y_test, cls_wght='balanced'
#)

# %% [markdown]
# I retain the TF-IDF Model with stemmatization as it provides the greatest performance and it is faster since it uses sparse vectors.
#
# In the following I concatenate the other features e.g. suppliers, purchasing organizations etc.

# %% [markdown]
# ### Train and Test Set Engineering

# %%
X_train = sp.sparse.hstack(
    [X_train_text_proc_stem, X_train_suppl_one, X_train_porg_one, X_train_comp_one, X_train_pgrp_one]
)
# X_train = sp.sparse.hstack([X_train_text_proc,X_train_suppl_one ])

X_test = sp.sparse.hstack(
    [X_test_text_proc_stem, X_test_suppl_one, X_test_porg_one, X_test_comp_one, X_test_pgrp_one]
)
# X_test = sp.sparse.hstack([X_test_text_proc,X_test_suppl_one])

# %%
dicts = [cats_map_text, cats_map_suppl,cats_map_porg,cats_map_comp, cats_map_prgp]  # List of dictionaries
categories_mapping = {}
counter = 0  # Start progressive index

for d in dicts:
    for value in d.values():
        categories_mapping[counter] = value
        counter += 1

len(categories_mapping)
# Out:
# 6056

# %%
X_train.shape
# Out:
# (311220, 6056)

# %% [markdown]
# Choosing the best model for level 1 among DecisionTree, Random Forest and Gradient Boosting

# %%
train_dist = train['puor_ds_level1_new'].value_counts(normalize=True)
test_dist = test['puor_ds_level1_new'].value_counts(normalize=True)

# %%
train_dist
# Out:
# SUPPLY CHAIN             0.571923
# TECHNICAL PROCUREMENT    0.247748
# GENERAL PROCUREMENT      0.180329
# Name: puor_ds_level1_new, dtype: float64

# %%
test_dist
# Out:
# GENERAL PROCUREMENT      0.552626
# TECHNICAL PROCUREMENT    0.440668
# SUPPLY CHAIN             0.006707
# Name: puor_ds_level1_new, dtype: float64

# %%
# # Inverse weighting: higher weight for underrepresented classes in training
# class_weights = {}
# 
# for cls in test_dist.index:
#     if cls in test_dist and test_dist[cls] > 0:
#         class_weights[cls] = test_dist.sum() / test_dist[cls]
#     else:
#         class_weights[cls] = 1e6  # Or np.inf
# 
# raw_weights = {cls: test_dist.sum() / test_dist[cls] if cls in test_dist else 1e6 for cls in test_dist.index}
# min_weight = min(raw_weights.values())
# class_weights = {cls: w / min_weight for cls, w in raw_weights.items()}
# # reducing weight of supply chain
# class_weights["SUPPLY CHAIN"]=class_weights["SUPPLY CHAIN"]/20

# %%
model(
    DecisionTreeClassifier, X_tr=X_train, y_tr=y_train, X_ts=X_test, y_ts=y_test, cls_wght='balanced'
)
# Out:
# Accuracy on training set: 0.945
# Accuracy on test set: 0.961
# Accuracy on test set by a DUMMY CLASSIFIER: 0.213
# Classification Report for Test Set
#                        precision    recall  f1-score   support
#
#   GENERAL PROCUREMENT       0.97      0.97      0.97     33866
#          SUPPLY CHAIN       0.56      0.63      0.59       411
# TECHNICAL PROCUREMENT       0.96      0.96      0.96     27005
#
#              accuracy                           0.96     61282
#             macro avg       0.83      0.85      0.84     61282
#          weighted avg       0.96      0.96      0.96     61282
#
# Classification Report for Training Set
#                        precision    recall  f1-score   support
#
#   GENERAL PROCUREMENT       0.79      0.94      0.86     56122
#          SUPPLY CHAIN       0.98      0.92      0.95    177994
# TECHNICAL PROCUREMENT       1.00      1.00      1.00     77104
#
#              accuracy                           0.94    311220
#             macro avg       0.92      0.95      0.94    311220
#          weighted avg       0.95      0.94      0.95    311220
# (DecisionTreeClassifier(class_weight='balanced', random_state=42),
#  array(['GENERAL PROCUREMENT', 'TECHNICAL PROCUREMENT',
#         'GENERAL PROCUREMENT', ..., 'GENERAL PROCUREMENT',
#         'GENERAL PROCUREMENT', 'TECHNICAL PROCUREMENT'], dtype=object),
#  0          GENERAL PROCUREMENT
#  1        TECHNICAL PROCUREMENT
#  2          GENERAL PROCUREMENT
#  3          GENERAL PROCUREMENT
#  4          GENERAL PROCUREMENT
#                   ...
#  65241      GENERAL PROCUREMENT
#  65242      GENERAL PROCUREMENT
#  65244      GENERAL PROCUREMENT
#  65245      GENERAL PROCUREMENT
#  65246    TECHNICAL PROCUREMENT
#  Name: puor_ds_level1_new, Length: 61282, dtype: object)

# %%
#model(
#    RandomForestClassifier, X_tr=X_train, y_tr=y_train, X_ts=X_test, y_ts=y_test, cls_wght='balanced', random_forest=True, n_ests=20
#)

# %%
#model(
#   GradientBoostingClassifier, X_tr=X_train, y_tr=y_train, X_ts=X_test, y_ts=y_test, gradient_boosting=True, n_ests=1000, lr=0.01
#)

# %% [markdown]
# Best Model: RandomForestClassifier

# %%
tree, y_predictions, y_gold_labels = model(
    RandomForestClassifier, X_tr=X_train, y_tr=y_train, X_ts=X_test, y_ts=y_test, cls_wght='balanced', n_ests=10
    #DecisionTreeClassifier, X_tr=X_train, y_tr=y_train, X_ts=X_test, y_ts=y_test, cls_wght='balanced'
)
# Out:
# Accuracy on training set: 0.946
# Accuracy on test set: 0.969
# Accuracy on test set by a DUMMY CLASSIFIER: 0.213
# Classification Report for Test Set
#                        precision    recall  f1-score   support
#
#   GENERAL PROCUREMENT       0.98      0.97      0.97     33866
#          SUPPLY CHAIN       0.64      0.63      0.64       411
# TECHNICAL PROCUREMENT       0.97      0.97      0.97     27005
#
#              accuracy                           0.97     61282
#             macro avg       0.86      0.86      0.86     61282
#          weighted avg       0.97      0.97      0.97     61282
#
# Classification Report for Training Set
#                        precision    recall  f1-score   support
#
#   GENERAL PROCUREMENT       0.80      0.94      0.86     56122
#          SUPPLY CHAIN       0.98      0.93      0.95    177994
# TECHNICAL PROCUREMENT       1.00      1.00      1.00     77104
#
#              accuracy                           0.95    311220
#             macro avg       0.93      0.95      0.94    311220
#          weighted avg       0.95      0.95      0.95    311220

# %%
features_imp = tree.feature_importances_
sort_idx = np.argsort(features_imp)[::-1]

# %%
for idx in sort_idx[:40]:
    print(f"Feature name: {categories_mapping[idx]}, Feature Importance: {features_imp[idx]}")
# Out:
# Feature name: transport, Feature Importance: 0.2570851501330995
# Feature name: SAPECCFE3_LU19, Feature Importance: 0.05906799153670124
# Feature name: SAPECCFE3_ITT3, Feature Importance: 0.05158192158508007
# Feature name: SAPECCFE3_ZA19, Feature Importance: 0.0500529561826934
# Feature name: SAPECCFE3_BE20, Feature Importance: 0.046300887750884964
# Feature name: SAPECCFE3_US29, Feature Importance: 0.03815106562723546
# Feature name: SAPECCFE3_AU10, Feature Importance: 0.0323174869014589
# Feature name: SAPECCFE3_NL09, Feature Importance: 0.03226894164384835
# Feature name: SAPECCFE3_BR10, Feature Importance: 0.019116136634691975
# Feature name: SAPECCFE3_O19, Feature Importance: 0.016720833070904228
# Feature name: SAPECCFE3_CH09, Feature Importance: 0.016483795268574325
# Feature name: SAPECCFE3_ES10, Feature Importance: 0.016447596588838598
# Feature name: SAPECCFE3_MX03, Feature Importance: 0.015686118264937703
# Feature name: SAPECCFE3_BG10, Feature Importance: 0.015463132218032735
# Feature name: SAPECCFE3_MX05, Feature Importance: 0.015461320056058872
# Feature name: SAPECCFE3_RS10, Feature Importance: 0.014825192026550185
# Feature name: SAPECCFE3_CN34, Feature Importance: 0.01474823402528413
# Feature name: SAPECCFE3_ID09, Feature Importance: 0.012276978612373098
# Feature name: SAPECCFE3_GB12, Feature Importance: 0.012245242999378587
# Feature name: SAPECCFE3_IN02, Feature Importance: 0.0114028601602125
# Feature name: SAPECCFE3_306, Feature Importance: 0.010353402770632698
# Feature name: SAPECCFE3_BR07, Feature Importance: 0.010059240572434633
# Feature name: SAPECCFE3_1LG, Feature Importance: 0.009052775025687108
# Feature name: SAPECCFE3_LU10, Feature Importance: 0.008534283813353683
# Feature name: SAPECCFE3_ITT5, Feature Importance: 0.008365146043911302
# Feature name: SAPECCFE3_CZ09, Feature Importance: 0.00800650510883624
# Feature name: SAPECCFE3_O17, Feature Importance: 0.006590305485021498
# Feature name: SAPECCFE3_IT1B, Feature Importance: 0.005598225858174615
# Feature name: SAPECCFIP_0000610214, Feature Importance: 0.005264298185712414
# Feature name: SAPECCFE3_ITG0, Feature Importance: 0.0048830001068711215
# Feature name: SAPECCFE3_AU03, Feature Importance: 0.004491144444078349
# Feature name: SAPECCFE3_DTM, Feature Importance: 0.004306960553705531
# Feature name: josedo, Feature Importance: 0.004052326786338542
# Feature name: sorp, Feature Importance: 0.003944583125706356
# Feature name: SAPECCFE3_BR05, Feature Importance: 0.0038660133939402465
# Feature name: SAPECCFE3_IT50, Feature Importance: 0.0036678173197313957
# Feature name: SAPECCFE3_TRI, Feature Importance: 0.003542763716407364
# Feature name: SAPECCFE3_0000196492, Feature Importance: 0.0035278325043870146
# Feature name: SAPECCFE3_0000030916, Feature Importance: 0.003518128597920994
# Feature name: SAPECCFE3_B06, Feature Importance: 0.003417662162657291

# %%
# gbrt = GradientBoostingClassifier(random_state=RANDOM_STATE)
# gbrt.fit(X_train, y_train)
#
# print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
# print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))

# %% [markdown]
# ### Integrating Level1 and Predicting Level2

# %%
X_train1, X_test1 = integrating_prev_lev_predict_next_lev(
    X_train, X_test, level="puor_ds_level1_new", model=tree
)
y_train1 = train.puor_ds_level2_new
y_test1 = test.puor_ds_level2_new
# Out:
# Number of features:3
# First five features:['GENERAL PROCUREMENT' 'SUPPLY CHAIN' 'TECHNICAL PROCUREMENT']

# %%
#tree1, y_predictions1, y_gold_labels1 = model(
#    DecisionTreeClassifier, X_tr=X_train1, y_tr=y_train1, X_ts=X_test1, y_ts=y_test1, cls_wght='balanced'
#)

# %%
tree1, y_predictions1, y_gold_labels1 = model(
    RandomForestClassifier, X_tr=X_train1, y_tr=y_train1, X_ts=X_test1, y_ts=y_test1, cls_wght='balanced', n_ests=10
)
# Out:
# Accuracy on training set: 0.941
# Accuracy on test set: 0.730
# Accuracy on test set by a DUMMY CLASSIFIER: 0.066
# Classification Report for Test Set
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                         precision    recall  f1-score   support
#
#                       AUTOMATION & MRO       0.71      0.72      0.72     13038
# CUSTOM BROKERAGE & FORWARDING AGENCIES       0.40      0.97      0.56       117
#                                 ENERGY       0.17      0.76      0.27       145
#       ENERGY AND UTILITIES FOR OFFICES       0.93      0.93      0.93        15
#            INFRASTRUCTURE & INDUSTRIAL       0.70      0.54      0.61      9292
#            IT - INFORMATION TECHNOLOGY       0.39      0.93      0.55       246
#                     MARKETING SERVICES       0.97      0.84      0.90     14748
#                               MOBILITY       0.64      0.90      0.75      1439
#                           OTHER NON GP       0.00      0.00      0.00         0
#                    PALLETTS PURCHASING       0.93      0.57      0.70        23
#                  PALLETTS RENT & LEASE       0.96      0.96      0.96        54
#                        PEOPLE SERVICES       0.70      0.56      0.62      4039
#                     PRIMARY TRANSPORTS       0.95      0.61      0.74        87
#                      PROCESS EQUIPMENT       0.41      0.53      0.46      4530
#                  PROFESSIONAL SERVICES       0.18      0.55      0.27       415
#                         SALES SERVICES       0.56      0.88      0.69      2740
#                      SECONDARY FREIGHT       0.87      0.76      0.81        59
#                            SURPRISE L2       0.08      1.00      0.14         1
#                            WAREHOUSING       0.58      0.96      0.72        71
#                     WORKPLACE SERVICES       0.89      0.84      0.87     10223
#
#                               accuracy                           0.73     61282
#                              macro avg       0.60      0.74      0.61     61282
#                           weighted avg       0.77      0.73      0.74     61282
#
# Classification Report for Training Set
#                                         precision    recall  f1-score   support
#
#                       AUTOMATION & MRO       1.00      0.97      0.98     66946
# CUSTOM BROKERAGE & FORWARDING AGENCIES       0.63      0.99      0.77      6014
#                                 ENERGY       0.51      1.00      0.68       143
#       ENERGY AND UTILITIES FOR OFFICES       0.99      0.99      0.99        99
#            INFRASTRUCTURE & INDUSTRIAL       0.87      0.97      0.92      8102
#            IT - INFORMATION TECHNOLOGY       0.99      0.99      0.99      3866
#                     MARKETING SERVICES       0.98      0.99      0.99      6809
#                               MOBILITY       0.97      0.98      0.98      2603
#                           OTHER NON GP       0.76      1.00      0.86        35
#                    PALLETTS PURCHASING       0.85      1.00      0.92        93
#                  PALLETTS RENT & LEASE       1.00      1.00      1.00       235
#                        PEOPLE SERVICES       0.95      0.97      0.96      3803
#                     PRIMARY TRANSPORTS       1.00      0.96      0.98    134525
#                      PROCESS EQUIPMENT       0.76      0.99      0.86      1913
#                  PROFESSIONAL SERVICES       0.88      0.98      0.93      2361
#                         SALES SERVICES       0.85      0.68      0.76     23905
#                      SECONDARY FREIGHT       0.81      0.91      0.86     34240
#                            SURPRISE L2       1.00      1.00      1.00       387
#                            WAREHOUSING       0.67      0.99      0.80      2887
#                     WORKPLACE SERVICES       0.97      0.97      0.97     12254
#
#                               accuracy                           0.94    311220
#                              macro avg       0.87      0.97      0.91    311220
#                           weighted avg       0.95      0.94      0.94    311220

# %%
#model(
#    GradientBoostingClassifier, X_tr=X_train1, y_tr=y_train1, X_ts=X_test1, y_ts=y_test1, gradient_boosting=True, n_ests=500, lr=0.01
#)

# %%
#X_test_lvl2_pred = tree1.predict(X_test1).reshape(-1, 1)
#n = 0
#range = np.arange(130, 140)
#for i in range + 1:
#    print(i)
#    print(f"PO Line: {test.puor_id_order_line.iloc[i]}")
#    if X_test_lvl2_pred[i][0] == test.puor_ds_level2_new.iloc[i]:
#        print("vvv CORRECT PREDICTION vvv")
#        n += 1
#    else:
#        print("xxx NOT CORRECT PREDICTION xxx")
#
#    print(f"Prediction is {X_test_lvl2_pred[i][0]}")
#    print(f"Truth is {test.puor_ds_level2_new.iloc[i]}")
#    print("------")
#print(f"Number of correct cases {n} out of {len(range)}")

# %% [markdown]
# ### Integrating Level2 and Predicting Level3

# %%
X_train2, X_test2 = integrating_prev_lev_predict_next_lev(
    X_train1, X_test1, level="puor_ds_level2_new", model=tree1
)
y_train2 = train.puor_ds_level3_new
y_test2 = test.puor_ds_level3_new
# Out:
# Number of features:20
# First five features:['AUTOMATION & MRO' 'CUSTOM BROKERAGE & FORWARDING AGENCIES' 'ENERGY'
#  'ENERGY AND UTILITIES FOR OFFICES' 'INFRASTRUCTURE & INDUSTRIAL']

# %%
#tree2, y_predictions2, y_gold_labels2 = model(
#    DecisionTreeClassifier, X_tr=X_train2, y_tr=y_train2, X_ts=X_test2, y_ts=y_test2, cls_wght='balanced'
#)

# %%
tree3, y_predictions3, y_gold_labels3 = model(
    RandomForestClassifier, X_tr=X_train2, y_tr=y_train2, X_ts=X_test2, y_ts=y_test2, cls_wght='balanced', n_ests=10
)
# Out:
# Accuracy on training set: 0.908
# Accuracy on test set: 0.675
# Accuracy on test set by a DUMMY CLASSIFIER: 0.033
# Classification Report for Test Set
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                            precision    recall  f1-score   support
#
#                                       ADMINISTRATION COST       0.00      0.00      0.00         0
#                                   ADMINISTRATIVE SERVICES       0.52      0.92      0.67        52
#                                 B&U PROFESSIONAL SERVICES       0.20      0.43      0.27       329
#                                            CERTIFICATIONS       0.75      0.58      0.65        26
#                                                  CLEANING       0.90      0.41      0.56      1876
#                                          CLEANING (LOCAL)       0.07      1.00      0.13        17
#                          COMMERCIAL QUALITY AND FRESHNESS       0.86      0.70      0.78        44
#                                      CONSULTANCY SERVICES       0.55      0.66      0.60       125
#                                CONSUMER RESEARCH (AD-HOC)       0.45      0.82      0.58       237
#                            CONSUMERS PROMOTION ACTIVITIES       0.67      0.54      0.60       328
#                                           CREATIVE DESIGN       0.98      0.61      0.75     10975
#                           CREATIVE DEVELOPMENT & STRATEGY       0.17      0.42      0.24       784
#                          DIGITAL & SOCIAL MEDIA MARKETING       0.50      0.61      0.55       725
#                                              DISTRIBUTION       1.00      0.86      0.93        59
#                                         EMPLOYEE SERVICES       0.42      0.69      0.52       726
#                                 EMPLOYEE SERVICES (LOCAL)       0.06      1.00      0.11         2
#                                       ENERGY CERTIFICATES       0.00      0.00      0.00         7
#                               ENERGY FOR INDUSTRIAL PLANT       0.95      1.00      0.98       138
#                                                    EVENTS       0.43      0.76      0.55       317
#                                            EVENTS (LOCAL)       0.18      0.67      0.29         3
#                      EXPORT OTHER COMMODITIES (AUTOMATIC)       0.00      0.00      0.00         0
# FACILITY MANAGEMENT HARDSERVICES FOR INDUSTRIAL LOCATIONS       0.67      0.33      0.44      1901
# FACILITY MANAGEMENT SOFTSERVICES FOR INDUSTRIAL LOCATIONS       0.83      0.63      0.72      3290
#                                                     FLEET       0.96      0.93      0.94       904
#                                             FLEET (LOCAL)       0.00      0.00      0.00         0
#                                             FOOD SERVICES       0.39      0.77      0.52       303
#                                     FOOD SERVICES (LOCAL)       0.91      0.97      0.94        60
#                               FREIGHT FORWARDING AGENCIES       0.99      0.98      0.99       117
#                                                   GADGETS       0.42      0.72      0.53       100
#                                                  HANDLING       0.98      0.85      0.91        48
#                   HARDWARE - PURCHASE/LEASING/MAINTENANCE       0.85      0.84      0.84        73
#                        INDUSTRIAL AUTOMATION AND ROBOTICS       0.72      0.40      0.51      2192
#                                            INFRASTRUCTURE       0.58      0.61      0.59      1451
#                                        INSURANCE SERVICES       0.39      0.88      0.54         8
#                         LABORATORY EQUIPMENT AND SERVICES       0.46      0.75      0.57      2321
#                                      LEGAL & TAX SERVICES       0.38      0.12      0.18        76
#                                  LEGAL CONSULTING (LOCAL)       0.00      0.00      0.00         0
#                                        LICENSING & RIGHTS       0.61      0.74      0.67       345
#                                MAINTENANCE & IMPROVEMENTS       0.25      0.78      0.38       512
#                        MAINTENANCE & IMPROVEMENTS (LOCAL)       0.42      0.06      0.10        85
#                                      MAINTENANCE SERVICES       0.48      0.75      0.58      1914
#                                        MARKET MEASUREMENT       0.38      0.40      0.39       144
#                                          MARKETING EVENTS       0.40      0.45      0.42        75
#              MERCHANDISING & HOSTESS & BROKER COMMISSIONS       0.65      0.80      0.72       303
#                                           MOLDING & OVENS       0.83      0.68      0.75      1295
#                      NUTS EQUIPMENT & AGRI MOBILE MACHINE       0.79      0.92      0.85       225
#                              OFFICE SUPPLIES AND SERVICES       0.93      0.80      0.86      6884
#                      OFFICE SUPPLIES AND SERVICES (LOCAL)       0.83      0.83      0.83        52
#                                     OTHER LOGISTICS COSTS       0.10      1.00      0.18         2
#                                      OTHER SALES SERVICES       0.65      0.68      0.67        57
#                                   PALLETTS PURCHASING MTL       1.00      1.00      1.00        23
#                                 PALLETTS RENT & LEASE SVC       1.00      1.00      1.00        54
#                                                   PAYROLL       0.83      0.67      0.74        73
#                                                   PICKING       0.80      0.89      0.84         9
#                                              POS MATERIAL       0.90      0.84      0.87      1571
#                                               PREPARATION       0.70      0.46      0.56       893
#                                         PRIMARY PACKAGING       0.71      0.58      0.64       209
#                                                PRODUCTION       0.24      0.70      0.36      1290
#                                         PROMOTIONAL ITEMS       0.30      0.62      0.40        87
#                                          PUBLIC RELATIONS       0.66      0.57      0.61       109
#                                               REAL ESTATE       0.19      0.47      0.27       191
#                                       REAL ESTATE (LOCAL)       0.85      0.79      0.81        14
#                                       RECRUITMENT SERVICE       0.14      0.79      0.23       111
#                                                RELOCATION       0.38      0.62      0.47        50
#                                             RETAIL PANELS       0.80      0.70      0.74       139
#                                            ROAD TRANSPORT       0.95      0.38      0.55        52
#                                             SEA TRANSPORT       0.51      0.58      0.54        33
#                                       SECONDARY PACKAGING       0.30      0.51      0.38       173
#                                                  SECURITY       0.75      0.82      0.79       212
#                                          SECURITY (LOCAL)       0.60      1.00      0.75         3
#                                SERVICES - MANAGED SERVICE       0.63      0.47      0.54        86
#                               SERVICES - T&M/BODY LEASING       0.66      0.64      0.65        78
#             SOFTWARE - MAINTENANCE FOR PERPETUAL LICENSES       0.00      0.00      0.00         3
#                         SOFTWARE - SUBSCRIPTIONS/LICENSES       0.12      0.67      0.21         6
#                                                SPONSORING       0.26      0.41      0.32        29
#                                      STANDALONE EQUIPMENT       0.37      0.58      0.45       340
#                                                   STORAGE       0.81      1.00      0.90        13
#                                 SUBSCRIPTIONS/MEMBERSHIPS       0.80      0.68      0.73       128
#                                               SURPRISE L3       1.00      1.00      1.00         1
#                                 TECHNICAL DEVICES FOR POS       0.58      0.60      0.59       146
#                        TECHNICAL MATERIALS, PPE & CLOTHES       0.88      0.84      0.86      8932
#                                       TEMPORARY PERSONNEL       0.61      0.83      0.70       223
#                               TEMPORARY PERSONNEL (LOCAL)       0.00      0.00      0.00         0
#                                                  TRAINING       0.90      0.42      0.58      2524
#                                          TRAINING (LOCAL)       0.25      0.10      0.14        10
#                                                    TRAVEL       0.95      0.93      0.94       535
#                                            TRAVEL (LOCAL)       0.00      0.00      0.00         0
#                                                 UTILITIES       0.07      0.79      0.12        14
#                             UTILITIES FOR OFFICES (LOCAL)       1.00      1.00      1.00        15
#                                      WAREHOUSE & LOGISTIC       0.84      0.96      0.90      1395
#                            WAREHOUSING LOCATION & LEASING       0.00      0.00      0.00         1
#                                          WASTE MANAGEMENT       0.00      0.00      0.00         0
#
#                                                  accuracy                           0.68     61282
#                                                 macro avg       0.54      0.62      0.54     61282
#                                              weighted avg       0.78      0.68      0.70     61282
#
# Classification Report for Training Set
#                                                            precision    recall  f1-score   support
#
#                                       ADMINISTRATION COST       0.96      0.98      0.97       231
#                                   ADMINISTRATIVE SERVICES       0.84      0.94      0.89       470
#                                     AIR FREIGHT TRANSPORT       0.60      1.00      0.75       104
#                                 B&U PROFESSIONAL SERVICES       0.73      0.96      0.83       428
#                               BONUS / MALUS (WAREHOUSING)       1.00      1.00      1.00         1
#                                            CERTIFICATIONS       0.59      0.99      0.74        83
#                                                  CLEANING       0.69      0.98      0.81       172
#                                          CLEANING (LOCAL)       0.93      1.00      0.96       179
#                          COMMERCIAL QUALITY AND FRESHNESS       0.85      0.99      0.92       130
#                                      CONSULTANCY SERVICES       0.89      0.93      0.91       321
#                                CONSUMER RESEARCH (AD-HOC)       0.98      0.98      0.98       663
#                            CONSUMERS PROMOTION ACTIVITIES       0.95      0.91      0.93      1188
#                                           CREATIVE DESIGN       0.91      0.99      0.95       419
#                           CREATIVE DEVELOPMENT & STRATEGY       0.97      0.98      0.97      1173
#                          DIGITAL & SOCIAL MEDIA MARKETING       0.93      0.98      0.95       937
#                                              DISTRIBUTION       0.82      0.88      0.85     34240
#                                         EMPLOYEE SERVICES       0.97      0.92      0.95      1655
#                                 EMPLOYEE SERVICES (LOCAL)       0.97      0.98      0.97       222
#                                       ENERGY CERTIFICATES       1.00      1.00      1.00         3
#                               ENERGY FOR INDUSTRIAL PLANT       0.61      0.96      0.75       140
#                                                    EVENTS       0.95      0.95      0.95       635
#                                            EVENTS (LOCAL)       0.87      1.00      0.93        13
#                      EXPORT OTHER COMMODITIES (AUTOMATIC)       0.11      0.81      0.19       631
# FACILITY MANAGEMENT HARDSERVICES FOR INDUSTRIAL LOCATIONS       0.72      0.98      0.83       941
# FACILITY MANAGEMENT SOFTSERVICES FOR INDUSTRIAL LOCATIONS       0.83      0.98      0.90      2266
#                                                     FLEET       0.99      0.97      0.98      1685
#                                             FLEET (LOCAL)       0.88      0.99      0.93       120
#                                             FOOD SERVICES       0.89      0.95      0.92       789
#                                     FOOD SERVICES (LOCAL)       1.00      1.00      1.00       258
#                               FREIGHT FORWARDING AGENCIES       0.71      0.96      0.81      6014
#                                                FUMIGATION       1.00      1.00      1.00         8
#                                                   GADGETS       0.73      0.94      0.82       276
#                                                  HANDLING       0.51      0.92      0.66       943
#                   HARDWARE - PURCHASE/LEASING/MAINTENANCE       0.99      0.97      0.98      1830
#                            HARDWARE - SUBSCRIPTIONS INFRA       0.48      1.00      0.65        21
#                        INDUSTRIAL AUTOMATION AND ROBOTICS       0.54      0.96      0.69       481
#                                            INFRASTRUCTURE       0.77      0.93      0.84       722
#                                        INSURANCE SERVICES       0.98      0.96      0.97       563
#                                INSURANCE SERVICES (LOCAL)       1.00      1.00      1.00         3
#                         LABORATORY EQUIPMENT AND SERVICES       0.90      0.96      0.93      3745
#                           LEGAL & NOTARY SERVICES (LOCAL)       1.00      1.00      1.00         3
#                                      LEGAL & TAX SERVICES       0.93      0.96      0.94       467
#                                  LEGAL CONSULTING (LOCAL)       1.00      1.00      1.00        39
#                                        LICENSING & RIGHTS       0.93      0.99      0.96       612
#                                MAINTENANCE & IMPROVEMENTS       0.93      0.94      0.93      1828
#                        MAINTENANCE & IMPROVEMENTS (LOCAL)       0.76      0.98      0.85        51
#                                      MAINTENANCE SERVICES       0.95      0.90      0.92      9119
#                                         MAN WORK PER HOUR       1.00      1.00      1.00         3
#                                        MARKET MEASUREMENT       0.97      0.98      0.98       610
#                                          MARKETING EVENTS       0.92      0.99      0.95        95
#              MERCHANDISING & HOSTESS & BROKER COMMISSIONS       0.93      0.95      0.94      1480
#                                           MOLDING & OVENS       0.67      0.97      0.79       415
#                      NUTS EQUIPMENT & AGRI MOBILE MACHINE       0.58      1.00      0.73        89
#                              OFFICE SUPPLIES AND SERVICES       0.97      0.97      0.97      7698
#                      OFFICE SUPPLIES AND SERVICES (LOCAL)       0.82      1.00      0.90       210
#                                  OTHER CONSULTING (LOCAL)       0.80      1.00      0.89         8
#                                     OTHER LOGISTICS COSTS       0.16      0.93      0.27       641
#                                     OTHER NON GP SERVICES       0.76      1.00      0.86        35
#                                      OTHER SALES SERVICES       0.84      0.99      0.91       223
#                OUTSOURCING - NETWORK TRANSMISSION (LOCAL)       0.97      0.95      0.96        38
#                                   PALLETTS PURCHASING MTL       0.85      1.00      0.92        93
#                                 PALLETTS RENT & LEASE SVC       1.00      1.00      1.00       235
#                                                   PAYROLL       0.71      0.98      0.82       195
#                                                   PICKING       0.73      0.97      0.84       230
#                                              POS MATERIAL       0.74      0.63      0.68     18632
#                                               PREPARATION       0.76      0.98      0.85       229
#                                         PRIMARY PACKAGING       0.82      1.00      0.90        95
#                                                PRODUCTION       0.98      0.96      0.97      1969
#                                         PROMOTIONAL ITEMS       0.95      0.98      0.97       744
#                                          PUBLIC RELATIONS       0.92      0.99      0.96        86
#                                            RAIL TRANSPORT       1.00      1.00      1.00         2
#                                               REAL ESTATE       0.97      0.97      0.97       403
#                                       REAL ESTATE (LOCAL)       0.92      1.00      0.96        59
#                                       RECRUITMENT SERVICE       0.86      0.97      0.91       357
#                                                RELOCATION       0.73      0.96      0.83       171
#                                                 REPACKING       1.00      1.00      1.00       321
#                                             RETAIL PANELS       0.97      0.96      0.97       340
#                                            ROAD TRANSPORT       1.00      0.91      0.95    130765
#                                             SEA TRANSPORT       0.68      0.82      0.74      2382
#                                       SECONDARY PACKAGING       0.74      0.99      0.85       171
#                                                  SECURITY       0.98      0.98      0.98       441
#                                          SECURITY (LOCAL)       0.89      1.00      0.94         8
#                                SERVICES - MANAGED SERVICE       0.98      0.96      0.97      1083
#                               SERVICES - T&M/BODY LEASING       0.94      0.96      0.95       413
#             SOFTWARE - MAINTENANCE FOR PERPETUAL LICENSES       0.87      0.94      0.90       128
#                         SOFTWARE - SUBSCRIPTIONS/LICENSES       0.92      0.94      0.93       353
#                                                SPONSORING       0.96      0.97      0.96       309
#                                      STANDALONE EQUIPMENT       0.72      1.00      0.83       230
#                                                   STORAGE       0.63      0.98      0.77      1048
#                                 SUBSCRIPTIONS/MEMBERSHIPS       0.90      0.95      0.93       404
#                                               SURPRISE L3       1.00      1.00      1.00       387
#                                 TECHNICAL DEVICES FOR POS       0.93      0.96      0.94       828
#                        TECHNICAL MATERIALS, PPE & CLOTHES       1.00      0.96      0.98     57346
#                                       TEMPORARY PERSONNEL       0.91      0.95      0.93       383
#                               TEMPORARY PERSONNEL (LOCAL)       1.00      1.00      1.00         3
#                                                  TRAINING       0.68      0.95      0.79       120
#                                          TRAINING (LOCAL)       0.91      1.00      0.95        49
#                                                    TRAVEL       0.96      0.95      0.96       791
#                                            TRAVEL (LOCAL)       1.00      1.00      1.00         7
#                                                 UTILITIES       0.66      0.96      0.78       158
#                             UTILITIES FOR OFFICES (LOCAL)       0.99      0.99      0.99        99
#                                      WAREHOUSE & LOGISTIC       0.86      0.98      0.92       684
#                            WAREHOUSING LOCATION & LEASING       0.98      1.00      0.99        89
#                                          WASTE MANAGEMENT       0.22      1.00      0.37        13
#
#                                                  accuracy                           0.91    311220
#                                                 macro avg       0.85      0.97      0.89    311220
#                                              weighted avg       0.93      0.91      0.92    311220

# %%
#model(
#    GradientBoostingClassifier, X_tr=X_train2, y_tr=y_train2, X_ts=X_test2, y_ts=y_test2, gradient_boosting=True, n_ests=1, lr=0.01
#)

# %%
#X_test_lvl3_pred = tree2.predict(X_test2).reshape(-1, 1)
#n = 0
#range = np.arange(130, 140)
#for i in range + 1:
#    print(i)
#    print(f"PO Line: {test.puor_id_order_line.iloc[i]}")
#    if X_test_lvl3_pred[i][0] == test.puor_ds_level3_new.iloc[i]:
#        print("vvv CORRECT PREDICTION vvv")
#        n += 1
#    else:
#        print("xxx NOT CORRECT PREDICTION xxx")
#
#    print(f"Prediction is {X_test_lvl3_pred[i][0]}")
#    print(f"Truth is {test.puor_ds_level3_new.iloc[i]}")
#    print("------")
#print(f"Number of correct cases {n} out of {len(range)}")

# %% [markdown]
# ### Integrating Level3 and Predicting Level4

# %%
X_train3, X_test3 = integrating_prev_lev_predict_next_lev(
    X_train2, X_test2, level="puor_ds_level3_new", model=tree3
)
y_train3 = train.puor_ds_level4_new
y_test3 = test.puor_ds_level4_new
# Out:
# Number of features:104
# First five features:['ADMINISTRATION COST' 'ADMINISTRATIVE SERVICES' 'AIR FREIGHT TRANSPORT'
#  'B&U PROFESSIONAL SERVICES' 'BONUS / MALUS\xa0(WAREHOUSING)']

# %%
tree3, y_predictions3, y_gold_labels3 = model(
    DecisionTreeClassifier, X_tr=X_train3, y_tr=y_train3, X_ts=X_test3, y_ts=y_test3, cls_wght='balanced'
)
# Out:
# Accuracy on training set: 0.878
# Accuracy on test set: 0.624
# Accuracy on test set by a DUMMY CLASSIFIER: 0.005
# Classification Report for Test Set
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                               precision    recall  f1-score   support
#
#                                             1/4 Wood Pallets       1.00      1.00      1.00        14
#                   1st Level Support Outsourcing Applications       0.49      0.85      0.62        26
#                     1st Level Support Outsourcing Technology       0.00      0.00      0.00        11
#                    2nd Level Suport Outsourcing Applications       0.00      0.00      0.00         0
#                     2nd Level Support Outsourcing Technology       0.00      0.00      0.00        37
#        Ad hoc reports/ analysis performed on Retail Panel DB       0.20      0.08      0.11        13
#        Ad hoc reports/analysis on syndicated data (excl RMS)       0.22      0.33      0.27        12
#          Additional Services and Costs for Real Estate Lease       0.27      0.88      0.41        26
#                             Administrative Costs Warehousing       0.00      0.00      0.00         0
#                         Application Perpetual Licenses CAPEX       1.00      1.00      1.00         1
#          Applications Development - System Integration CAPEX       0.33      1.00      0.50         1
#                           Applications Development T&M CAPEX       0.00      0.00      0.00         1
#                         Applications Run and Maintenance T&M       0.98      0.87      0.92        46
#                                           Archiving Services       0.09      0.37      0.15        27
#                               Automation Technical Materials       0.71      0.65      0.68      1053
#                             Automation professional services       0.53      0.51      0.52       612
#                                                  Axes/shafts       0.00      0.00      0.00         3
#                                   BEARINGS AND LINEAR GUIDES       0.30      0.61      0.40        49
#                                          BRAKES AND CLUTCHES       0.60      0.60      0.60         5
#                                         BUILDING MAINTENANCE       0.78      0.71      0.74       145
#                                                    Batteries       0.26      1.00      0.41         6
#                                                        Belts       0.63      0.65      0.64       170
#                Booking System Services - Third Parties (TBD)       0.00      0.00      0.00         0
#             Books, periodicals subscription (digital or not)       0.86      0.90      0.88        81
#                               Brand & Communication Strategy       0.40      0.10      0.15       177
#                                       Brand promotion events       1.00      0.85      0.92        59
#                                           Broker Commissions       0.62      0.89      0.73        18
#                                                      Brushes       0.42      0.81      0.56        21
#         Building Third Party - Improvements & Equipment Cost       0.10      1.00      0.18         1
#                                           Building materials       0.32      0.45      0.38        51
#               Building owned - Improvements & equipment cost       0.88      0.65      0.75        75
#                           Building owned - Improvements cost       0.10      0.73      0.18        11
#                                    Business Association fees       0.93      0.75      0.83        36
#                                             CANTEEN SERVICES       0.91      0.91      0.91       204
#                                                         CCTV       0.40      0.40      0.40         5
#                                            CHEMICAL MATERIAL       0.45      0.47      0.46       179
#                                          CONTROL INSTRUMENTS       0.00      0.00      0.00       118
#               CPX - Agri mobile machine (tractor, harvester)       0.50      0.86      0.63         7
#                                   CPX - Automatic Warehouses       0.02      0.10      0.04        10
#                        CPX - Automation and Digital Software       0.08      0.16      0.11        19
#                                       CPX - Bagging Machines       0.00      0.00      0.00        15
#                                                  CPX - Basin       0.64      0.85      0.73        66
#                                                  CPX - Belts       0.03      0.55      0.06        11
#                                    CPX - Box Forming Machine       0.40      0.57      0.47        14
#                                          CPX - Check weigher       0.67      0.29      0.40        69
#                                          CPX - Cocoa Presses       0.00      0.00      0.00         3
#                                      CPX - Conveying Systems       0.08      0.20      0.11         5
#                                 CPX - Conveyors and Handling       0.88      0.52      0.66       109
#        CPX - Conveyors,Elevators,Transports, Big Bag station       0.75      0.21      0.33        14
#                            CPX - Counter and filling machine       0.14      0.14      0.14        37
#                                         CPX - Deodorizations       0.10      1.00      0.18         1
#                                      CPX - Dosing & Enrobing       0.08      0.02      0.04        88
#                                      CPX - Dough Preparation       0.00      0.00      0.00         9
#                                           CPX - Flow wrapper       0.88      0.68      0.77        68
#                                        CPX - Forklifts (Buy)       0.00      0.00      0.00         6
#                           CPX - Forming, filling and closing       0.84      0.87      0.85       127
#                                     CPX - General Contractor       0.33      0.05      0.09        38
#                                         CPX - Gluing machine       0.71      0.38      0.50        13
#                                       CPX - Handling Systems       0.11      0.33      0.16         6
#         CPX - Infeed (incl. raw distributor system / buffer)       1.00      0.40      0.57        15
#                                              CPX - Labellers       1.00      0.30      0.46        27
#                           CPX - Liquid Handling & Processing       0.90      0.44      0.59       576
#                                         CPX - Metal detector       0.17      0.07      0.10        14
#                             CPX - Metal structures and pipes       0.00      0.00      0.00         7
#                      CPX - Molding :  Ferrero Design & Build       0.06      0.85      0.12        13
#                                      CPX - Molding equipment       0.61      0.40      0.48       213
#                           CPX - Molds and Forming Equipments       0.93      0.52      0.66       730
#                                        CPX - Optical sorters       1.00      0.93      0.96        42
#                                                   CPX - Oven       0.12      0.23      0.16        13
#                      CPX - Packaging: Ferrero Design & Build       0.00      0.00      0.00         4
#                                   CPX - Pal- & Depalletizers       0.57      0.57      0.57        14
#                                            CPX - Picker line       0.00      0.00      0.00         2
#                                             CPX - Plate Oven       0.09      0.36      0.14        11
#                           CPX - Powder handling & processing       0.13      0.23      0.17        31
#                      CPX - Pre-Cleaning/Drying/Vacuum system       1.00      0.18      0.31        11
#                                                CPX - Printer       0.53      0.87      0.66        78
#           CPX - Refiners (incl. prerefiners, conches, mills)       0.71      0.50      0.59        98
#                                                CPX - Roaster       0.04      0.57      0.07        14
#                                        CPX - Sealing machine       0.08      0.50      0.13         4
#                              CPX - Services in project scope       0.00      0.00      0.00       100
#                                               CPX - Shellers       0.04      0.33      0.07         6
#                                                  CPX - Silos       0.86      0.06      0.12        96
#                               CPX - Sleeve & Shrink Machines       1.00      1.00      1.00         1
#                    CPX - Tanks (incl. mixer, plastificators)       0.56      0.30      0.39       150
#                                              CPX - Tempering       0.24      0.97      0.39        80
#                                        CPX - Thermic tunnels       0.50      0.12      0.20        16
#                                          CPX - Thermoforming       0.18      0.29      0.22         7
#                                       CPX - Vision & Cameras       0.22      0.39      0.28        18
#                                    CPX - Warehousing - Racks       0.31      0.69      0.43        32
#                                      CPX - Wrapping machines       0.37      0.39      0.38        74
#                                                  CPX - X-Ray       0.15      0.75      0.25        12
#                       CPX Electrical and Automation Cabinets       0.66      0.50      0.57       423
#                    CPX Industrial robotic application system       0.52      0.52      0.52        27
#                                       CPX Technical Material       0.04      0.50      0.08         8
#                                 CPX: Civil Equipment / Works       0.62      0.48      0.54       616
#                     CPX: Electrical Equipment & Installation       0.24      0.31      0.27       212
#                   CPX: Energy (Sustainability) / Investments       0.33      0.03      0.06        29
#                                               CPX: Equipment       0.34      0.39      0.36       140
#                                      CPX: General Contractos       0.93      0.74      0.83       281
#                     CPX: Mechanical Equipment & Installation       0.13      0.09      0.10       270
#                             CPX: Waste Water & Gas Treatment       0.00      0.00      0.00         2
#                                  CUSTOM DECLARATION SERVICES       1.00      0.40      0.57        10
#                                                         Cams       0.33      0.50      0.40         6
#                                               Cash Donations       0.00      0.00      0.00         0
#                                            Catering services       0.77      0.77      0.77        39
#                                                       Chains       0.52      0.73      0.61        33
#                                 Check Out Display Production       0.80      0.44      0.57         9
#                                            Civil maintenance       0.59      0.93      0.72       965
#                            Cleaning Consultancy and Services       0.97      0.88      0.92      1648
# Cleaning, Waste,Pest Services and Material for No Industrial       1.00      1.00      1.00      1876
#                                 Client receivables insurance       0.00      0.00      0.00         0
#                        Cloud License Application Maintenance       0.50      1.00      0.67         1
#             Cod - PPE, Safety Work Products, Fire Protection       0.42      0.19      0.26       343
#                  Codified - Clothes & Uniforms, Safety Shoes       0.40      0.14      0.21       239
#                  Commercial Quality and Freshness monitoring       1.00      1.00      1.00        44
#                        Communication POS material Production       0.62      0.61      0.61       241
#                       Company Vehicles - Fuel, Oil and other       0.93      0.88      0.91       161
#                                     Company Vehicles - Lease       0.90      0.96      0.93       339
#                         Company Vehicles - Maintenance costs       0.97      0.89      0.93       382
#                          Company Vehicles - Management costs       0.32      0.89      0.47         9
#                            Company Vehicles - Other vehicles       1.00      1.00      1.00         6
#                                  Company Vehicles - Purchase       1.00      0.43      0.60         7
#                                           Computer (process)       0.18      0.50      0.27         4
#                                                   Consumable       0.88      0.72      0.80      1559
#                        Consumer panel on-going subscriptions       0.78      0.45      0.57        84
#                                       Control Tower Services       0.00      0.00      0.00         1
#      Corporate IT Management, Finance and Administration T&M       1.00      0.50      0.67         6
#                                     Corporate event Expenses       0.91      0.93      0.92       202
#                                                    Couplings       0.00      0.00      0.00         5
#           Creative Concept for Advertising Campaigns DIGITAL       0.42      0.77      0.55       225
#       Creative Concept for Advertising Campaigns TRADITIONAL       0.84      0.74      0.79       382
#            Customs Docum./Forwarder Services Finish Products       0.70      0.61      0.65        64
#     Customs Docum./Forwarder Services Interm-Finished Prd-FI       0.11      0.33      0.17         6
#                  Customs Docum./Forwarder Services Packaging       0.00      0.00      0.00         2
#              Customs Docum./Forwarder Services RAW MATERIALS       0.16      0.60      0.25         5
#        Customs Docum./Forwarder Services SEMI-FINISHED GOODS       1.00      1.00      1.00         1
#                  Customs Docum./Forwarder Services Surprises       1.00      0.07      0.13        29
#                                                Cutting tools       0.38      0.58      0.46        24
#                                                    Cylinders       0.61      0.76      0.67        75
#                                                      Dampers       0.50      0.20      0.29        10
#        Data source provider, knowledge database subscription       0.00      0.00      0.00         0
#                     Design & Management of Digital Promotion       0.81      0.69      0.74        42
#                 Design & Management of non Digital Promotion       0.93      0.89      0.91       229
#                                              Design Services       0.95      0.51      0.67       276
#                                             Discount Coupons       0.70      0.81      0.75        57
#  Distribution to Customers and Returned Goods from Customers       0.98      0.98      0.98        58
#                                                    Donations       0.00      0.00      0.00         0
#                                       Donations to employees       0.65      0.57      0.61        61
#                                               Dosing nozzles       0.14      0.09      0.11        11
#                  E-commerce Advertising Creative Development       0.45      0.85      0.59        82
#                            E-commerce Advertising Production       0.31      0.75      0.44        12
#                                   ELECTRIC MOTORS AND DRIVES       0.40      0.71      0.51        52
#                         ELECTRICAL / ELECTRONICAL COMPONENTS       0.35      0.42      0.38       400
#                                          EXPORT EXPENSES FOR       0.00      0.00      0.00         1
#                                              Electric cables       0.15      0.62      0.24         8
#                       Electrical Energy for Industrial Plant       0.93      0.87      0.90        61
#                                       Electrical Maintenance       0.92      0.24      0.38       461
#                                            Electronic cables       0.20      0.44      0.27        16
#                                 Employees Transport Services       0.81      0.66      0.73        65
#                   Employees event and social activities cost       0.56      0.77      0.65       139
#                                Employees relocation services       0.90      0.71      0.79        38
#                                       Employees tax services       1.00      0.50      0.67         4
#         End-User Computing Mobile Communications Outsourcing       0.00      0.00      0.00         0
#             End-User Computing Mobile Management Outsourcing       1.00      1.00      1.00         2
#                                       End-User Computing T&M       0.40      1.00      0.57         4
#                                Energy certifications for gas       0.00      0.00      0.00         4
#                              Energy certifications for power       0.43      1.00      0.60         3
#                       Entertainment expenses (No deductible)       0.50      0.61      0.55        18
#                                       Environmental Analysis       0.00      0.00      0.00         0
#                                      Epal 80x120 Pallets New       0.00      0.00      0.00         8
#                          Epal 80x120 Pallets Used 1st Choice       0.14      1.00      0.25         1
#                            Events Sponsorships & Partnership       1.00      1.00      1.00        29
#                            Export Expenses For Various Sales       0.00      0.00      0.00         0
#                        Extra Cost  Transpor Finished product       1.00      1.00      1.00         4
#                               Extra Cost  Transpor Packaging       0.00      0.00      0.00         0
#                                  Extra-waiting RAW MATERIALS       1.00      1.00      1.00         2
#                                              FIXING ELEMENTS       0.17      0.53      0.26        49
#                                                         Fans       0.15      0.44      0.22         9
#                                                      Filters       0.51      0.78      0.62        79
#                                              Financial Audit       0.09      0.75      0.16         4
#                                               Flexible pipes       0.35      0.78      0.48        18
#                         Forklift And Machinery Rentals (Ops)       0.30      0.75      0.43         4
#                                             Fraud Management       0.00      0.00      0.00         1
#  Fridges lease/rent and other tech devices for point of Sale       0.92      0.85      0.88        53
#    Fridges production and other tech devices for POS - CAPEX       0.94      0.94      0.94        17
# Fridges production and other tech devices for POS-excl CAPEX       0.00      0.00      0.00         2
#                                    Fuel for industrial plant       0.50      0.94      0.65        16
#                                                        Fuels       0.92      0.51      0.66        47
#                  Function related / professional consultancy       0.86      0.59      0.70        95
#                                                       GADGET       0.57      0.67      0.62        12
#                                                 GADGET OTHER       0.00      0.00      0.00         0
#                                                        GEARS       0.27      0.43      0.33         7
#                                              Gas Consumables       0.73      0.83      0.78        59
#                                     Gas for Industrial Plant       0.96      0.80      0.88        61
#                                                Gaskets/Seals       0.20      0.55      0.30        44
#                                                    Gearboxes       0.06      0.41      0.10        17
#                                          Generic consumables       0.21      0.27      0.24       310
#                                                        Glues       0.16      0.07      0.10        59
# Ground and green areas maintenance,inclu industrial premises       0.43      0.48      0.45        31
#                             HYDRAULIC AND PNEUMATIC FITTINGS       0.27      0.44      0.34        45
#                                     Handling Finish Products       0.50      0.06      0.11        16
#                                            Handling Services       0.63      0.96      0.76        28
#                        Hardware - Leasing End-User Computing       0.67      0.80      0.73         5
#        Hardware - Leasing High Value Server&Storage (>5000$)       0.60      1.00      0.75         3
#                                  Hardware - Leasing Printers       1.00      0.40      0.57         5
#                                       Hardware - Maintenance       0.83      0.73      0.78        26
#                        Hardware - Maintenance Server&Storage       1.00      0.82      0.90        11
#                Hardware - Maintenance Voice and Data Network       1.00      0.33      0.50         6
#                 Hardware - Purchase End-User Computing CAPEX       0.00      0.00      0.00         1
#                     Hardware - Purchase Server&Storage CAPEX       0.50      0.50      0.50         2
#             Hardware - Purchase Voice and Data Network CAPEX       0.54      1.00      0.70         7
#                       Hardware - Purchase for Mobile devices       0.62      0.83      0.71         6
#              Hardware - Purchase for Videoconference devices       0.00      0.00      0.00         1
#                         Health and Safety - Site Supervision       0.06      0.33      0.10         3
#                                         Health and Safety GP       0.77      0.74      0.75       193
#                                                      Heaters       0.38      0.30      0.33        10
#                                             Hostess services       0.85      0.92      0.88       148
#                                          Hotel accommodation       0.68      0.70      0.69        37
#                                          IT Service Desk T&M       0.00      0.00      0.00        21
#                          ITL - Altre spese di rappresentanza       0.00      0.00      0.00         0
#                                ITL - Spese di rappresentanza       1.00      0.33      0.50         3
#                           In-Pack Gadgets_Commercial Co-Pack       0.87      0.74      0.80        35
#                           In-Pack Gadgets_Industrial co-pack       0.70      0.61      0.65        46
#            In/Out Functional Display Production - Customized       0.42      0.49      0.45        47
#              In/Out Functional Display Production - Standard       0.83      0.59      0.69       482
#          In/Out Theatrical Materials Production - Customized       0.49      0.61      0.55        70
#            In/Out Theatrical Materials Production - Standard       0.77      0.64      0.70       143
#                                   Industrial 100x120 Pallets       0.00      0.00      0.00         0
#                                          Industrial Cleaning       0.69      0.82      0.75        55
#                                                    Infirmary       0.05      0.25      0.09         4
#                                   Influencers & Testimonials       0.65      0.68      0.67        25
#                                       Institutional Expenses       0.00      0.00      0.00        14
#                              Integrated Facility Maintenance       0.05      0.30      0.09        10
#                                                 Job postings       0.11      0.67      0.18        12
#                                                   Laboratory       0.29      0.61      0.39        96
#                                             Laundry Services       0.33      0.43      0.38         7
#                                               Legal Advisory       0.91      0.97      0.94        66
#                                               Legal services       1.00      0.67      0.80         6
#                                                       Levers       0.50      0.33      0.40         3
#                                        Liability (Insurance)       0.00      0.00      0.00         4
#                         Licensing - Brands & Content DIGITAL       0.15      0.18      0.16        17
#                     Licensing - Brands & Content TRADITIONAL       0.56      0.73      0.64        49
#                                    Licensing - Music DIGITAL       0.64      0.56      0.60        62
#                                Licensing - Music TRADITIONAL       0.00      0.00      0.00         4
#                                                     Lighting       0.05      0.70      0.09        10
#                                    Local Small Building rent       0.00      0.00      0.00         1
#                                               Locks, Handles       0.12      0.12      0.12        17
#                                         Long Stay Relocation       0.45      0.75      0.56        12
#                                      Long stay accommodation       0.29      0.25      0.27        16
#                                                   Lubricants       0.77      0.81      0.79        63
#                                    M&A related consultancies       0.00      0.00      0.00         9
#       Maintenace service not depreciable (Maintenance Order)       0.36      0.11      0.17       224
#            Maintenance And Services On Laboratory Equipments       0.17      0.53      0.25       115
#                             Maintenance Application Software       0.00      0.00      0.00         2
#                      Maintenance End-User Computing Software       0.00      0.00      0.00         0
#                          Maintenance Server&Storage Software       0.00      0.00      0.00         1
#                  Maintenance Voice and Data Network Software       0.00      0.00      0.00         0
#                                     Manned guarding services       0.86      0.83      0.85       109
#                      Measure devices and Control instruments       0.04      0.11      0.06        27
#                                       Mechanical maintenance       0.67      0.28      0.40       465
#                    Media Relations, Membership & Partnership       0.00      0.00      0.00         2
#                                             Medical Services       0.84      0.84      0.84       148
#                                       Merchandising services       0.94      0.80      0.87       137
#                                               NGO, Donations       0.14      0.09      0.11        11
#                                   No Commercial Sponsorships       0.22      0.50      0.31         4
#         Not cod - PPE, Safety Work Products, Fire Protection       0.15      0.24      0.18       715
#              Not codified - Clothes & Uniforms, Safety Shoes       0.06      0.02      0.03       188
#               OPX - Agri Mobile Machine (Tractor, Harvester)       0.03      0.75      0.06         4
#                              OPX - Extraordinary Maintenance       0.57      0.35      0.44        48
#                           OPX - Forklifts (Rental & Service)       0.97      0.94      0.96      1301
#                                   OPX - Ordinary Maintenance       0.84      0.73      0.78      1518
#             OPX - Retrofit/revamping of an equipment or line       0.15      0.15      0.15        13
#                      OPX - Software, Licence Fee, Assistance       0.20      0.83      0.32        58
#                                         OTHER LOGISTIC COSTS       0.67      1.00      0.80         2
#                                         OTHER SALE DISCOUNTS       0.00      0.00      0.00         0
#                                     Office Furniture - Capex       0.47      0.89      0.61       382
#                     Office machines & equipment - Investment       0.84      0.82      0.83        56
#                    Office machines & equipment - Maintenance       0.54      0.65      0.59        48
#                                              Office supplies       0.81      0.81      0.81      4053
#                                 Optional insurance employees       0.00      0.00      0.00         1
#                                   Optional insurance manager       0.00      0.00      0.00         0
#               Other Consumables, Material and Small Supplies       0.85      0.36      0.51      2035
#          Other Materials Immediate Use for Maintenance Plant       0.55      0.41      0.47      1691
#      Other Materials Immediate Use for Production Assistance       0.00      0.00      0.00        44
#           Other Spare parts (not codified, catalogues items)       0.62      0.35      0.44      2958
#                                               Other auditing       0.82      0.21      0.34        42
#   Other research activities on consumer, shopper and citizen       0.67      0.35      0.46        46
#          Other syndicated subscriptions (excluding RMS, CPS)       0.31      0.81      0.45        21
#                                        Other travel services       0.68      0.83      0.75        18
#                 Outsourcing of administrative services (bpo)       0.40      1.00      0.57         2
#                                                      PALLETS       1.00      1.00      1.00         1
#                                             PAYROLL SERVICES       1.00      1.00      1.00        73
#                            PHOTOCELLS AND PROXIMITY SWITCHES       0.44      0.76      0.56        45
#                          POS material Development & Sampling       0.41      0.90      0.57       130
#                 POS material Molds, Toolings, Die Cuts CAPEX       0.00      0.00      0.00         6
#                           POS materials Storage and Logistic       0.82      0.57      0.67       288
#       PR Communication Strategy, Advisory, Issues Management       0.69      0.48      0.57        75
#                                PR Digital Activities & Tools       0.27      0.83      0.41        18
#                                         PRINTERS CONSUMABLES       0.28      0.73      0.40        22
#                                         PRINTERS SPARE PARTS       0.67      0.48      0.56        25
#                                             PRODUCTION TOOLS       0.16      0.11      0.13        74
#                                            PROM.MAT.CASHDESK       0.00      0.00      0.00         0
#                                             PROMO POS MODERN       0.00      0.00      0.00         0
#                                             PROMO POS TRADNL       0.00      0.00      0.00         0
#                                            PROMOTIONAL GIFTS       0.00      0.00      0.00         0
#                                    PROMOTIONAL POINT OF SALE       0.43      0.70      0.53       164
#  Packaging & POS - Artwork, Technical finalization&Templates       0.09      0.77      0.17       115
#                           Packaging & POS - Creative Concept       0.81      0.66      0.72      7186
#                          Packaging & POS - Mockups / Samples       0.33      0.26      0.29      2041
#                                                        Paint       0.56      0.36      0.43        14
#                                         Panel SPE management       0.67      0.67      0.67         6
#                                     People Security Services       0.41      0.35      0.38        20
#         Permanent Materials Production - Secondary Placement       0.87      0.86      0.86        56
#                                           Personal Insurance       0.00      0.00      0.00         2
#                                                 Pest Control       0.67      0.79      0.73       109
#                           Physical and Supply Chain security       1.00      0.55      0.71        11
#                                      Picking Finish Products       1.00      1.00      1.00         8
#                                             Picking Services       1.00      1.00      1.00         1
#                Plant Utilities EaaS (Equipment as a Service)       0.06      0.42      0.10        12
#                                Porter and reception services       0.33      0.62      0.43         8
#               Post-Production of Advertising Content DIGITAL       0.37      0.39      0.38       109
#           Post-Production of Advertising Content TRADITIONAL       0.68      0.68      0.68       418
#                                      Postage & Couriers Fees       0.25      0.71      0.36       110
#                                            Printing Supplies       0.53      0.77      0.63       213
#               Printing, photography and videomaking services       0.07      0.42      0.12        24
#                    Process Engineering professional services       0.51      0.63      0.56        59
#                    Production of Advertising Content DIGITAL       0.57      0.64      0.61       360
#        Production of Advertising Content TRADITIONAL - Radio       0.51      0.60      0.55       109
#          Production of Advertising Content TRADITIONAL - TVC       0.56      0.61      0.59        57
#     Production of Advertising Content TRADITIONAL-OOH,Static       0.68      0.38      0.49       237
#              Promotional items (including consumer giveaway)       1.00      0.98      0.99        87
#                       Property Cost Estimation & Acquisition       0.75      1.00      0.86         3
#                                         Property acquisition       0.08      1.00      0.15         4
#                                        Public relation costs       0.86      0.82      0.84        93
#                                                      Pulleys       0.25      0.75      0.38         4
#                                                        Pumps       0.25      0.76      0.38        17
#                               Purchase Applications Licenses       0.67      0.67      0.67         3
#                                 Purchase of product sampling       1.00      0.29      0.44         7
#                                                  RECRUITMENT       0.97      0.92      0.94        99
#                                     Real Estate Office Lease       0.96      0.40      0.56       134
#                      Real Estate Short-Term Lease <12 Months       0.43      0.90      0.58        21
#                                     Real estate Retail lease       1.00      1.00      1.00         6
#          Real estate others (no industrial, no supply chain)       1.00      0.33      0.50         3
#                                Recreation employees benefits       0.73      0.66      0.70        71
#                                   Rental 1/2 Plastic Pallets       1.00      1.00      1.00         1
#                                   Rental 1/4 Plastic Pallets       0.96      0.98      0.97        51
#                                        Rental 80x120 Pallets       0.00      0.00      0.00         1
#                            Rental Industrial 100x120 Pallets       0.00      0.00      0.00         1
#                                          Rental Services Fee       0.18      0.55      0.27        11
#                                  Research & Development cost       0.28      0.26      0.27        19
#    Research activities for qualifying Innovation initiatives       0.58      0.75      0.65        59
#    Research activities to assess the ADV/Communication Perf.       0.69      0.77      0.73        79
#         Researches to understand Consumers, Shopper, Markets       0.58      0.53      0.55        53
#                                       Retail Data monitoring       0.85      0.98      0.91        48
#                                             Retail Panels DB       0.90      0.82      0.86       123
# Rights buyout-Authors,Artists,Performers,Personality DIGITAL       0.32      0.48      0.39        48
#   Rights buyout-Authors,Artists,Performers,Personality TRADI       0.68      0.61      0.64       165
#                                                  Rigid pipes       0.12      0.38      0.18        24
#                                         Road Finish Products       0.00      0.00      0.00        12
#                                               Road Packaging       0.21      1.00      0.35         4
#                                          Road Transportation       0.93      0.46      0.62        28
#           Road Transportation Finished Products Export Costs       1.00      1.00      1.00         1
#                                                      Rollers       0.07      0.40      0.12         5
#                                                      SEO/SEM       0.00      0.00      0.00         9
#                                   SPARE PARTS FOR GAS PLANTS       0.50      0.12      0.20         8
#                                  SPECIFIC DRAWING COMPONENTS       0.24      0.52      0.33        42
#                                              SPROCKET WHEELS       0.03      0.67      0.05         3
#                                             SUNDRY INSURANCE       0.00      0.00      0.00         1
#                                              Safety supplies       0.37      0.82      0.51        40
#                                         Sales and B2B Events       0.33      0.11      0.17         9
#                                  School & Kinder garden fees       0.39      0.67      0.49        18
#                                                       Screws       0.19      0.76      0.31        25
#                                          Sea Finish Products       1.00      0.19      0.32        32
#                                            Sea RAW MATERIALS       0.00      0.00      0.00         0
#                                                Sea Surprises       0.00      0.00      0.00         0
#                         Sea Transportation Export Fees Costs       0.07      1.00      0.12         1
#                                          Security technology       0.74      0.86      0.79        58
#                                   Server&Storage Outsourcing       0.00      0.00      0.00         0
#                                           Server&Storage T&M       0.00      0.00      0.00         0
#                                     Server&Storage T&M CAPEX       0.00      0.00      0.00         0
#                                              Services Gadget       0.40      0.86      0.55         7
# Services for fridge and other tech devices for Point of Sale       0.23      0.33      0.27         9
#                                             Site supervision       0.17      0.29      0.21        28
#                                      Social Media Management       0.79      0.76      0.77       286
#                                      Spare Parts - Conveyors       0.19      0.48      0.27        25
#                                        Spare Parts Utilities       0.01      0.01      0.01        79
#                                             Spare parts kits       0.00      0.00      0.00         7
#      Specific Material For Utilities Machinery And Equipment       0.24      0.64      0.34        25
#                                                      Springs       0.21      0.60      0.32         5
#                                      Standard certifications       1.00      0.38      0.56        26
#                                      Storage Finish Products       0.67      0.67      0.67         3
#                                                  Storage Mtl       0.83      0.62      0.71         8
#                                        Storage RAW MATERIALS       0.50      1.00      0.67         2
#            Strategic, Managerial & organizational consulting       0.19      0.48      0.27        21
#                   Subscription Voice and Data Network (IaaS)       0.00      0.00      0.00         1
#           Subscriptions on Market measurement (license fees)       0.43      0.86      0.57        14
#                Subscriptions on Retail panels (license fees)       0.22      0.67      0.33         3
#                                                 Suction cups       0.70      0.70      0.70        20
#                        Surprises - Creative Concepts DIGITAL       0.09      0.03      0.05        88
#                    Surprises - Creative Concepts TRADITIONAL       0.17      0.56      0.27       375
#                                 Surprises - Marketing Sheets       0.64      0.25      0.36       737
#                            Surprises - Technical Development       0.30      0.71      0.42       433
#                                           TICKETS RESTAURANT       0.84      0.78      0.81        60
#                TR - Accessories technology supplies (GenAdm)       0.00      0.00      0.00         0
#                             TR - Archiving Services (GenAdm)       1.00      1.00      1.00         3
#                           TR - Building Maintenance (GenAdm)       0.00      0.00      0.00         0
#                               TR - Canteen Services (GenAdm)       0.82      0.86      0.84        37
#                              TR - Canteen Services (GenProd)       0.76      0.70      0.73        23
#                              TR - Cleaning services (GenAdm)       0.90      0.90      0.90        10
#                             TR - Cleaning services (GenProd)       0.86      0.86      0.86         7
#                                    TR - ELECTRICITY (GENADM)       1.00      1.00      1.00         3
#                                   TR - ELECTRICITY (GENPROD)       1.00      1.00      1.00         8
#             TR - Ground and green areas maintenance (GenAdm)       1.00      1.00      1.00        81
#                              TR - Handyman services (GenAdm)       1.00      0.75      0.86         4
#                             TR - Health and Safety (GenProd)       1.00      1.00      1.00         2
#                                TR - Office supplies (GenAdm)       1.00      0.89      0.94         9
#                               TR - Office supplies (GenProd)       0.75      0.75      0.75         4
#                                TR - People Security (GenAdm)       1.00      1.00      1.00         3
#                        TR - Postage & Couriers Fees (GenAdm)       0.54      1.00      0.70         7
#                       TR - Postage & Couriers Fees (GenProd)       0.00      0.00      0.00         2
#                       TR - Real Estate Office Lease (GenAdm)       1.00      1.00      1.00        14
#                                TR - Safety supplies (GenAdm)       0.00      0.00      0.00         0
#                         TR - Small Furniture - Opex (GenAdm)       0.00      0.00      0.00         1
#                        TR - Small Furniture - Opex (GenProd)       0.00      0.00      0.00         1
#                                       TR - Tolls and parking       1.00      0.84      0.91        25
#                    TR - Training costs of personnel (GenAdm)       0.00      0.00      0.00         0
#                   TR - Training costs of personnel (GenProd)       1.00      0.10      0.18        10
#                                          TR - WATER (GENADM)       1.00      1.00      1.00         2
#                                         TR - WATER (GENPROD)       1.00      1.00      1.00         2
#  TR-Specific Mtl For Warehouse, Lift And Handl. Equip.(S-Wh)       0.36      0.34      0.35        41
#                                  Tax & Customs Services Cost       0.00      0.00      0.00         4
#                                  Technical Cleaning material       0.86      0.78      0.82      1435
#              Technical Consultancy And External Lab Analysis       0.81      0.53      0.64       232
# Technical certifications, engineering-related consulting(TS)       0.10      0.58      0.17        19
#                                         Temporary Personnels       1.00      0.91      0.95       223
#                                           Testimonials Costs       0.64      1.00      0.78        16
#                           Training Design & Cost of Personal       1.00      0.95      0.97      2524
#                       Translations and interpreting services       0.75      0.58      0.65        31
#                                          Transport Surprises       0.00      0.00      0.00         0
#                                     Transportation - Flights       0.50      0.33      0.40        12
#                                       Transportation - Other       0.71      0.87      0.78        78
#                      Transportation - Short-term Rental Cars       0.89      0.87      0.88       214
#                              Travel Agencies fees & services       0.76      0.72      0.74       160
#                      Utilities - Electric Energy for Offices       0.88      0.88      0.88         8
#                                       Utilities - Office Gas       0.50      1.00      0.67         2
#                                     Utilities - Office Water       1.00      0.75      0.86         4
#                                                       Valves       0.36      0.64      0.46        58
#                                                    Vibrators       0.01      0.33      0.03         3
# ...
#                                           SUND.LOCAL TX&DUTY       1.00      1.00      1.00        22
#                                             SUNDRY INSURANCE       1.00      0.89      0.94       138
#                                              Safety supplies       0.79      0.96      0.87       211
#                                         Sales and B2B Events       0.77      1.00      0.87        17
#                                  School & Kinder garden fees       0.44      0.98      0.61        47
#                                                       Screws       0.96      0.92      0.94      1089
#                                          Sea Finish Products       0.05      0.67      0.09        43
#                                   Sea Interm-Finished Prd-FI       0.41      0.86      0.56        14
#                                                Sea Packaging       0.37      0.95      0.53        19
#                                            Sea RAW MATERIALS       0.91      0.92      0.92       184
#                                      Sea SEMI-FINISHED GOODS       0.15      0.81      0.26        26
#                                                Sea Surprises       0.63      1.00      0.77       118
#                                           Sea Transportation       0.99      0.99      0.99       569
#                         Sea Transportation Export Fees Costs       0.81      0.50      0.62      1409
#                                          Security technology       0.97      0.97      0.97       120
#                                Server&Storage Licenses CAPEX       1.00      1.00      1.00         4
#                                   Server&Storage Outsourcing       1.00      0.93      0.97        30
#                                           Server&Storage T&M       0.88      0.88      0.88        16
#                                     Server&Storage T&M CAPEX       0.82      1.00      0.90         9
#                                              Services Gadget       1.00      1.00      1.00        10
#                               Services for credit collection       0.60      1.00      0.75         6
# Services for fridge and other tech devices for Point of Sale       0.93      0.98      0.95        41
#                                             Site supervision       0.94      1.00      0.97        17
#                                      Social Media Management       0.98      0.99      0.99       320
#                                      Spare Parts - Conveyors       0.97      0.93      0.95      1560
#                                        Spare Parts Utilities       0.92      0.96      0.94       455
#                                             Spare parts kits       0.92      0.88      0.90       767
#                             Special Projects Finish Products       1.00      1.00      1.00         1
#      Specific Material For Utilities Machinery And Equipment       0.20      1.00      0.34        19
#                                                      Springs       0.91      0.92      0.92       332
#                                      Standard certifications       0.93      1.00      0.96        27
#                                      Storage Finish Products       0.32      0.95      0.48        37
#                       Storage Finished Products (co-packing)       0.95      1.00      0.97        38
#                               Storage Interm-Finished Prd-FI       1.00      1.00      1.00        77
#                                                  Storage Mtl       0.87      0.93      0.90       420
#                                            Storage Packaging       0.92      0.57      0.70       121
#                                        Storage RAW MATERIALS       0.87      0.81      0.84        83
#                                  Storage SEMI-FINISHED GOODS       0.03      1.00      0.05         5
#                                            Storage Surprises       0.77      0.42      0.55       266
#            Strategic, Managerial & organizational consulting       0.90      0.97      0.93       116
#                       Subscription End-User Computing (SaaS)       0.96      0.92      0.94        26
#                   Subscription Voice and Data Network (IaaS)       0.79      1.00      0.88        23
#           Subscriptions on Market measurement (license fees)       0.92      0.90      0.91       191
#                Subscriptions on Retail panels (license fees)       0.88      1.00      0.94        15
#                                                 Suction cups       0.92      0.95      0.94       432
#                        Surprises - Creative Concepts DIGITAL       1.00      1.00      1.00         4
#                    Surprises - Creative Concepts TRADITIONAL       0.50      1.00      0.67        11
#                                 Surprises - Marketing Sheets       1.00      0.71      0.83        21
#                            Surprises - Technical Development       0.88      1.00      0.94        15
#                                      Surprises certification       0.91      0.97      0.94        30
#                                           TICKETS RESTAURANT       0.88      0.93      0.91       118
#                TR - Accessories technology supplies (GenAdm)       1.00      1.00      1.00         1
#               TR - Accessories technology supplies (GenProd)       1.00      1.00      1.00         1
#                             TR - Archiving Services (GenAdm)       1.00      1.00      1.00        21
#                           TR - Building Maintenance (GenAdm)       1.00      0.95      0.97        20
#                               TR - Canteen Services (GenAdm)       1.00      0.98      0.99       163
#                              TR - Canteen Services (GenProd)       0.95      1.00      0.97        95
#                              TR - Cleaning services (GenAdm)       0.99      0.96      0.97        81
#                             TR - Cleaning services (GenProd)       0.94      0.97      0.95        74
#         TR - Company Vehicles - Fuel, Oil and other (GenAdm)       0.87      0.89      0.88        44
#        TR - Company Vehicles - Fuel, Oil and other (GenProd)       0.63      0.93      0.75        29
#                       TR - Company Vehicles - Lease (GenAdm)       0.97      0.82      0.89        34
#                      TR - Company Vehicles - Lease (GenProd)       0.56      0.71      0.63         7
#                         TR - Company Vehicles - Lease (S-Wh)       0.62      1.00      0.77         5
#          TR - Company Vehicles - Maintenance costs (GenProd)       1.00      1.00      1.00         1
#                         TR - Donations to employees (GenAdm)       1.00      1.00      1.00         4
#                                    TR - ELECTRICITY (GENADM)       1.00      1.00      1.00        12
#                                   TR - ELECTRICITY (GENPROD)       0.97      1.00      0.99        34
#                   TR - Employees Transport Services (GenAdm)       0.98      1.00      0.99        40
#                  TR - Employees Transport Services (GenProd)       1.00      0.98      0.99        61
#     TR - Employees event and social activities cost (GenAdm)       0.93      1.00      0.97        14
#    TR - Employees event and social activities cost (GenProd)       1.00      1.00      1.00         2
#                    TR - Expenses for notary charges (GenAdm)       1.00      1.00      1.00         3
#                                           TR - GAS (GENPROD)       1.00      1.00      1.00         6
#             TR - Ground and green areas maintenance (GenAdm)       0.27      1.00      0.43         6
#            TR - Ground and green areas maintenance (GenProd)       1.00      1.00      1.00         4
#                               TR - HR&OI Consulting (GenAdm)       1.00      1.00      1.00         6
#                              TR - Handyman services (GenAdm)       1.00      1.00      1.00        16
#                              TR - Health and Safety (GenAdm)       0.61      1.00      0.76        17
#                             TR - Health and Safety (GenProd)       0.93      0.97      0.95        71
#        TR - IA & Corporate Communication consulting (GenAdm)       1.00      1.00      1.00         2
#                               TR - Legal consulting (GenAdm)       1.00      1.00      1.00        33
#                                TR - Office supplies (GenAdm)       0.96      0.98      0.97        53
#                               TR - Office supplies (GenProd)       1.00      1.00      1.00        16
#                 TR - Opx Voice, Data Network-Transms(GenAdm)       0.97      0.95      0.96        38
#                          TR - Other Fuel Exp - no deductible       0.67      1.00      0.80         2
#                      TR - PURCHASE DISTRICT HEATING (GENADM)       0.72      1.00      0.84        18
#                                TR - People Security (GenAdm)       1.00      1.00      1.00         5
#                             TR - Personal insurance (GenAdm)       1.00      1.00      1.00         2
#                         TR - Pest Control services (GenProd)       1.00      0.96      0.98        24
#                        TR - Postage & Couriers Fees (GenAdm)       1.00      0.95      0.98        22
#                       TR - Postage & Couriers Fees (GenProd)       0.29      1.00      0.44        14
#                             TR - Printing Supplies (GenProd)       1.00      1.00      1.00         2
#                       TR - Real Estate Office Lease (GenAdm)       1.00      0.90      0.95        59
#                                TR - Safety supplies (GenAdm)       1.00      1.00      1.00         2
#                            TR - Security technology (GenAdm)       0.75      1.00      0.86         3
#                         TR - Small Furniture - Opex (GenAdm)       1.00      1.00      1.00         2
#                        TR - Small Furniture - Opex (GenProd)       1.00      1.00      1.00         2
#                               TR - Sundry insurance (GenAdm)       1.00      1.00      1.00         1
#  TR - Technical Consulting non-Industrial Buildings (GenAdm)       0.75      1.00      0.86         6
#                            TR - Temporary personnel (GenAdm)       1.00      1.00      1.00         1
#                           TR - Temporary personnel (GenProd)       1.00      1.00      1.00         2
#                                       TR - Tolls and parking       0.97      0.92      0.94        74
#                    TR - Training costs of personnel (GenAdm)       0.93      0.96      0.95        27
#                   TR - Training costs of personnel (GenProd)       0.85      1.00      0.92        22
#         TR - Translations and interpreting services (GenAdm)       1.00      0.92      0.96        13
#                TR - Travel Agencies fees & services (GenAdm)       1.00      1.00      1.00         5
#               TR - Travel Agencies fees & services (GenProd)       1.00      1.00      1.00         2
#                                          TR - WATER (GENADM)       1.00      0.94      0.97        16
#                                         TR - WATER (GENPROD)       1.00      1.00      1.00        31
# TR - Waste treatment, recycling and disposal services (S-Wh)       1.00      1.00      1.00         2
#  TR-Specific Mtl For Warehouse, Lift And Handl. Equip.(S-Wh)       0.82      1.00      0.90        18
# TR-Waste treatment,recycling and disposal services (GenProd)       1.00      1.00      1.00         3
#                                  Tax & Customs Services Cost       1.00      1.00      1.00         7
#                                  Technical Cleaning material       0.94      0.90      0.92      1588
#              Technical Consultancy And External Lab Analysis       0.96      0.90      0.93       291
# Technical certifications, engineering-related consulting(TS)       0.74      0.97      0.84       113
#                                         Temporary Personnels       0.97      0.88      0.93       383
#                                           Testimonials Costs       0.97      1.00      0.98        30
#                           Training Design & Cost of Personal       0.81      0.93      0.86       120
#                       Translations and interpreting services       0.86      0.95      0.90        84
#                              Transport Intermediate Products       0.09      0.30      0.13       314
#                                          Transport Packaging       0.06      1.00      0.12         1
#                                      Transport Raw Materials       0.07      1.00      0.13         2
#                                      Transport Semi Finished       0.25      0.64      0.36       295
#                                          Transport Surprises       0.03      0.95      0.05        19
#                                     Transportation - Flights       0.91      1.00      0.95        10
#                                       Transportation - Other       0.65      0.99      0.78        77
#                      Transportation - Short-term Rental Cars       0.97      0.92      0.95       273
#                              Travel Agencies fees & services       0.96      0.87      0.92       326
#                                             Travel insurance       1.00      1.00      1.00         1
#                      Utilities - Electric Energy for Offices       0.85      0.91      0.88       100
#                                       Utilities - Office Gas       0.32      1.00      0.49        19
#                                     Utilities - Office Water       0.95      1.00      0.97        39
#                                                       Valves       0.91      0.90      0.90      1529
#                                                    Vibrators       0.19      0.94      0.31        47
#            Voice and Data Network Communications Outsourcing       0.99      0.89      0.93       244
#                        Voice and Data Network Licenses CAPEX       1.00      1.00      1.00         2
#                           Voice and Data Network Outsourcing       0.74      0.96      0.84        27
#                                   Voice and Data Network T&M       0.43      1.00      0.60        16
#                                              WAREHOUSE LEASE       0.98      1.00      0.99        56
#                                               WORKSHOP TOOLS       0.97      0.94      0.96      2899
#                                               Warehouse Rent       0.96      1.00      0.98        27
#      Warehouse Rental Other Costs (cleaning, security, etc…)       1.00      1.00      1.00         6
#                                         Waste Management Svc       0.27      0.92      0.41        13
#                     Waste Management for industrial location       0.72      0.96      0.82        82
#                               Waste Water Treatment Services       1.00      0.91      0.95        11
#             Waste treatment, recycling and disposal services       0.98      0.93      0.95       325
#                                   Water for industrial plant       0.43      0.98      0.60        49
#                                        Web domain management       1.00      1.00      1.00         2
#                         Website / App Creation & Maintenance       0.96      0.96      0.96       284
#                                                       Wheels       0.42      0.95      0.58       163
#                                                 Сonstruction       0.89      0.92      0.90       613
#
#                                                     accuracy                           0.88    311220
#                                                    macro avg       0.82      0.95      0.85    311220
#                                                 weighted avg       0.91      0.88      0.89    311220

# %%
tree4, y_predictions4, y_gold_labels4 = model(
    RandomForestClassifier, X_tr=X_train3, y_tr=y_train3, X_ts=X_test3, y_ts=y_test3, cls_wght='balanced', n_ests=10
)
# Out:
# Accuracy on training set: 0.880
# Accuracy on test set: 0.650
# Accuracy on test set by a DUMMY CLASSIFIER: 0.005
# Classification Report for Test Set
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\riccardoricci\AppData\Roaming\Python\Python39\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                               precision    recall  f1-score   support
#
#                                             1/4 Wood Pallets       1.00      1.00      1.00        14
#                   1st Level Support Outsourcing Applications       0.39      0.92      0.55        26
#                     1st Level Support Outsourcing Technology       0.00      0.00      0.00        11
#                     2nd Level Support Outsourcing Technology       0.00      0.00      0.00        37
#        Ad hoc reports/ analysis performed on Retail Panel DB       0.50      0.08      0.13        13
#        Ad hoc reports/analysis on syndicated data (excl RMS)       0.27      0.33      0.30        12
#          Additional Services and Costs for Real Estate Lease       0.26      1.00      0.41        26
#                         Application Perpetual Licenses CAPEX       1.00      1.00      1.00         1
#          Applications Development - System Integration CAPEX       1.00      1.00      1.00         1
#                           Applications Development T&M CAPEX       0.00      0.00      0.00         1
#                         Applications Run and Maintenance T&M       0.94      0.96      0.95        46
#                                           Archiving Services       0.38      0.41      0.39        27
#                               Automation Technical Materials       0.78      0.76      0.77      1053
#                             Automation professional services       0.63      0.62      0.62       612
#                                                  Axes/shafts       0.00      0.00      0.00         3
#                                   BEARINGS AND LINEAR GUIDES       0.36      0.65      0.46        49
#                                          BRAKES AND CLUTCHES       0.75      0.60      0.67         5
#                                         BUILDING MAINTENANCE       0.77      0.79      0.78       145
#                                                    Batteries       0.26      1.00      0.41         6
#                                                        Belts       0.62      0.65      0.63       170
#             Books, periodicals subscription (digital or not)       0.83      0.91      0.87        81
#                               Brand & Communication Strategy       0.43      0.07      0.13       177
#                                       Brand promotion events       1.00      0.92      0.96        59
#                                           Broker Commissions       0.20      0.11      0.14        18
#                                                      Brushes       0.41      0.81      0.55        21
#         Building Third Party - Improvements & Equipment Cost       0.10      1.00      0.18         1
#                                           Building materials       0.59      0.37      0.46        51
#               Building owned - Improvements & equipment cost       0.87      0.80      0.83        75
#                           Building owned - Improvements cost       0.15      0.73      0.25        11
#                                    Business Association fees       0.81      0.61      0.70        36
#                                             CANTEEN SERVICES       0.89      0.93      0.91       204
#                                                         CCTV       0.75      0.60      0.67         5
#                                            CHEMICAL MATERIAL       0.46      0.47      0.47       179
#                                          CONTROL INSTRUMENTS       0.00      0.00      0.00       118
#               CPX - Agri mobile machine (tractor, harvester)       0.78      1.00      0.88         7
#                                   CPX - Automatic Warehouses       0.05      0.20      0.08        10
#                        CPX - Automation and Digital Software       0.07      0.16      0.10        19
#                                       CPX - Bagging Machines       0.00      0.00      0.00        15
#                                                  CPX - Basin       0.64      0.85      0.73        66
#                                                  CPX - Belts       0.02      0.64      0.05        11
#                                    CPX - Box Forming Machine       0.40      0.57      0.47        14
#                                          CPX - Check weigher       0.61      0.29      0.39        69
#                                          CPX - Cocoa Presses       0.00      0.00      0.00         3
#                                      CPX - Conveying Systems       0.14      0.40      0.21         5
#                                 CPX - Conveyors and Handling       0.89      0.57      0.69       109
#        CPX - Conveyors,Elevators,Transports, Big Bag station       1.00      0.21      0.35        14
#                            CPX - Counter and filling machine       0.14      0.14      0.14        37
#                                         CPX - Deodorizations       0.17      1.00      0.29         1
#                                      CPX - Dosing & Enrobing       0.12      0.05      0.07        88
#                                      CPX - Dough Preparation       0.00      0.00      0.00         9
#                                           CPX - Flow wrapper       0.93      0.74      0.82        68
#                                        CPX - Forklifts (Buy)       0.00      0.00      0.00         6
#                           CPX - Forming, filling and closing       0.85      0.90      0.87       127
#                                     CPX - General Contractor       0.00      0.00      0.00        38
#                                         CPX - Gluing machine       1.00      1.00      1.00        13
#                                       CPX - Handling Systems       0.07      0.33      0.12         6
#         CPX - Infeed (incl. raw distributor system / buffer)       0.42      0.33      0.37        15
#                                              CPX - Labellers       0.89      0.30      0.44        27
#                           CPX - Liquid Handling & Processing       0.85      0.41      0.55       576
#                                         CPX - Metal detector       0.00      0.00      0.00        14
#                             CPX - Metal structures and pipes       0.00      0.00      0.00         7
#                      CPX - Molding :  Ferrero Design & Build       0.06      0.77      0.11        13
#                                      CPX - Molding equipment       0.61      0.44      0.51       213
#                           CPX - Molds and Forming Equipments       0.95      0.52      0.67       730
#                                        CPX - Optical sorters       1.00      0.93      0.96        42
#                                                   CPX - Oven       0.17      0.38      0.24        13
#                      CPX - Packaging: Ferrero Design & Build       0.00      0.00      0.00         4
#                                   CPX - Pal- & Depalletizers       0.62      0.57      0.59        14
#                                            CPX - Picker line       0.00      0.00      0.00         2
#                                             CPX - Plate Oven       0.10      0.36      0.16        11
#                           CPX - Powder handling & processing       0.14      0.32      0.19        31
#                      CPX - Pre-Cleaning/Drying/Vacuum system       1.00      0.64      0.78        11
#                                                CPX - Printer       0.54      0.88      0.67        78
#           CPX - Refiners (incl. prerefiners, conches, mills)       0.40      0.46      0.43        98
#                                                CPX - Roaster       0.58      0.50      0.54        14
#                                        CPX - Sealing machine       0.00      0.00      0.00         4
#                              CPX - Services in project scope       0.00      0.00      0.00       100
#                                               CPX - Shellers       0.03      0.33      0.06         6
#                                                  CPX - Silos       0.91      0.98      0.94        96
#                               CPX - Sleeve & Shrink Machines       1.00      1.00      1.00         1
#                    CPX - Tanks (incl. mixer, plastificators)       0.53      0.39      0.45       150
#                                              CPX - Tempering       0.32      0.99      0.48        80
#                                        CPX - Thermic tunnels       0.00      0.00      0.00        16
#                                          CPX - Thermoforming       1.00      0.14      0.25         7
#                                       CPX - Vision & Cameras       0.89      0.44      0.59        18
#                                    CPX - Warehousing - Racks       0.88      0.69      0.77        32
#                                      CPX - Wrapping machines       0.44      0.59      0.51        74
#                                                  CPX - X-Ray       0.14      0.83      0.24        12
#                       CPX Electrical and Automation Cabinets       0.60      0.54      0.57       423
#                    CPX Industrial robotic application system       0.70      0.52      0.60        27
#                                       CPX Technical Material       0.04      0.50      0.07         8
#                                 CPX: Civil Equipment / Works       0.67      0.81      0.73       616
#                     CPX: Electrical Equipment & Installation       0.80      0.28      0.41       212
#                   CPX: Energy (Sustainability) / Investments       0.25      0.03      0.06        29
#                                               CPX: Equipment       0.42      0.32      0.37       140
#                                      CPX: General Contractos       0.95      0.79      0.86       281
#                     CPX: Mechanical Equipment & Installation       0.11      0.07      0.09       270
#                             CPX: Waste Water & Gas Treatment       0.00      0.00      0.00         2
#                                  CUSTOM DECLARATION SERVICES       1.00      0.40      0.57        10
#                                                         Cams       0.27      0.50      0.35         6
#                                            Cargo (Insurance)       0.00      0.00      0.00         0
#                                               Cash Donations       0.00      0.00      0.00         0
#                                            Catering services       0.81      0.77      0.79        39
#                                                       Chains       0.56      0.73      0.63        33
#                                 Check Out Display Production       0.75      0.33      0.46         9
#                                            Civil maintenance       0.57      0.98      0.72       965
#                            Cleaning Consultancy and Services       0.97      0.89      0.93      1648
# Cleaning, Waste,Pest Services and Material for No Industrial       1.00      1.00      1.00      1876
#                                 Client receivables insurance       0.00      0.00      0.00         0
#                        Cloud License Application Maintenance       0.50      1.00      0.67         1
#             Cod - PPE, Safety Work Products, Fire Protection       0.43      0.20      0.27       343
#                  Codified - Clothes & Uniforms, Safety Shoes       0.39      0.13      0.19       239
#                  Commercial Quality and Freshness monitoring       1.00      1.00      1.00        44
#                        Communication POS material Production       0.60      0.63      0.62       241
#                       Company Vehicles - Fuel, Oil and other       0.93      0.91      0.92       161
#                                     Company Vehicles - Lease       0.90      0.96      0.93       339
#                         Company Vehicles - Maintenance costs       0.97      0.90      0.93       382
#                          Company Vehicles - Management costs       0.36      0.89      0.52         9
#                            Company Vehicles - Other vehicles       1.00      1.00      1.00         6
#                                  Company Vehicles - Purchase       1.00      0.43      0.60         7
#                                           Computer (process)       0.09      0.50      0.15         4
#                                                   Consumable       0.89      0.76      0.82      1559
#                        Consumer panel on-going subscriptions       0.83      0.71      0.77        84
#                                       Control Tower Services       0.00      0.00      0.00         1
#      Corporate IT Management, Finance and Administration T&M       0.20      0.50      0.29         6
#                                     Corporate event Expenses       0.92      0.95      0.93       202
#                                                    Couplings       0.00      0.00      0.00         5
#           Creative Concept for Advertising Campaigns DIGITAL       0.42      0.76      0.54       225
#       Creative Concept for Advertising Campaigns TRADITIONAL       0.84      0.78      0.81       382
#            Customs Docum./Forwarder Services Finish Products       0.57      0.53      0.55        64
#     Customs Docum./Forwarder Services Interm-Finished Prd-FI       0.33      0.33      0.33         6
#                  Customs Docum./Forwarder Services Packaging       0.29      1.00      0.44         2
#              Customs Docum./Forwarder Services RAW MATERIALS       0.13      0.60      0.21         5
#        Customs Docum./Forwarder Services SEMI-FINISHED GOODS       0.00      0.00      0.00         1
#                  Customs Docum./Forwarder Services Surprises       1.00      0.07      0.13        29
#                                                Cutting tools       0.54      0.58      0.56        24
#                                              Cyber Insurance       0.00      0.00      0.00         0
#                                                    Cylinders       0.59      0.77      0.67        75
#                                                      Dampers       0.40      0.20      0.27        10
#        Data source provider, knowledge database subscription       0.00      0.00      0.00         0
#                     Design & Management of Digital Promotion       0.85      0.69      0.76        42
#                 Design & Management of non Digital Promotion       0.95      0.87      0.91       229
#                                              Design Services       0.94      0.65      0.77       276
#                                             Discount Coupons       0.55      0.81      0.66        57
#  Distribution to Customers and Returned Goods from Customers       0.98      0.98      0.98        58
#                                                    Donations       0.00      0.00      0.00         0
#                                       Donations to employees       0.65      0.49      0.56        61
#                                               Dosing nozzles       0.11      0.09      0.10        11
#                  E-commerce Advertising Creative Development       0.48      0.87      0.61        82
#                            E-commerce Advertising Production       0.32      0.75      0.45        12
#                                   ELECTRIC MOTORS AND DRIVES       0.53      0.71      0.61        52
#                         ELECTRICAL / ELECTRONICAL COMPONENTS       0.35      0.41      0.38       400
#                                          EXPORT EXPENSES FOR       0.00      0.00      0.00         1
#                                              Electric cables       0.17      0.62      0.27         8
#                       Electrical Energy for Industrial Plant       0.72      0.89      0.79        61
#                                       Electrical Maintenance       0.92      0.15      0.26       461
#                                            Electronic cables       0.16      0.44      0.23        16
#                                 Employees Transport Services       0.90      0.69      0.78        65
#                   Employees event and social activities cost       0.51      0.82      0.63       139
#                                Employees relocation services       0.90      0.74      0.81        38
#                                       Employees tax services       1.00      0.50      0.67         4
#         End-User Computing Mobile Communications Outsourcing       0.00      0.00      0.00         0
#             End-User Computing Mobile Management Outsourcing       1.00      1.00      1.00         2
#                                       End-User Computing T&M       0.40      1.00      0.57         4
#                                Energy certifications for gas       0.00      0.00      0.00         4
#                              Energy certifications for power       0.43      1.00      0.60         3
#                       Entertainment expenses (No deductible)       0.59      0.56      0.57        18
#                                       Environmental Analysis       0.00      0.00      0.00         0
#                                      Epal 80x120 Pallets New       0.00      0.00      0.00         8
#                          Epal 80x120 Pallets Used 1st Choice       0.00      0.00      0.00         1
#                            Events Sponsorships & Partnership       1.00      1.00      1.00        29
#                            Export Expenses For Various Sales       0.00      0.00      0.00         0
#                        Extra Cost  Transpor Finished product       1.00      1.00      1.00         4
#                                  Extra-waiting RAW MATERIALS       1.00      1.00      1.00         2
#                                              FIXING ELEMENTS       0.30      0.51      0.38        49
#                                                         Fans       0.26      0.89      0.40         9
#                                                      Filters       0.54      0.86      0.66        79
#                                              Financial Audit       0.07      0.75      0.13         4
#                                               Flexible pipes       0.27      0.78      0.41        18
#                         Forklift And Machinery Rentals (Ops)       0.30      0.75      0.43         4
#                                             Fraud Management       0.00      0.00      0.00         1
#  Fridges lease/rent and other tech devices for point of Sale       0.94      0.85      0.89        53
#    Fridges production and other tech devices for POS - CAPEX       0.94      0.94      0.94        17
# Fridges production and other tech devices for POS-excl CAPEX       0.00      0.00      0.00         2
#                                    Fuel for industrial plant       0.58      0.44      0.50        16
#                                                        Fuels       0.92      0.51      0.66        47
#                  Function related / professional consultancy       0.84      0.68      0.76        95
#                                                       GADGET       0.43      0.75      0.55        12
#                                                        GEARS       0.25      0.43      0.32         7
#                                              Gas Consumables       0.71      0.86      0.78        59
#                                     Gas for Industrial Plant       0.96      0.80      0.88        61
#                                                Gaskets/Seals       0.24      0.68      0.36        44
#                                                    Gearboxes       0.38      0.53      0.44        17
#                                          Generic consumables       0.21      0.26      0.23       310
#                                                        Glues       0.14      0.07      0.09        59
# Ground and green areas maintenance,inclu industrial premises       0.47      0.55      0.51        31
#                             HYDRAULIC AND PNEUMATIC FITTINGS       0.29      0.44      0.35        45
#                                     Handling Finish Products       1.00      0.06      0.12        16
#                                            Handling Services       0.64      1.00      0.78        28
#                        Hardware - Leasing End-User Computing       0.67      0.80      0.73         5
#        Hardware - Leasing High Value Server&Storage (>5000$)       0.60      1.00      0.75         3
#                                  Hardware - Leasing Printers       1.00      0.40      0.57         5
#                                       Hardware - Maintenance       0.68      0.73      0.70        26
#                        Hardware - Maintenance Server&Storage       0.90      0.82      0.86        11
#                Hardware - Maintenance Voice and Data Network       1.00      0.33      0.50         6
#                 Hardware - Purchase End-User Computing CAPEX       0.00      0.00      0.00         1
#                     Hardware - Purchase Server&Storage CAPEX       1.00      0.50      0.67         2
#             Hardware - Purchase Voice and Data Network CAPEX       0.56      0.71      0.63         7
#                       Hardware - Purchase for Mobile devices       0.62      0.83      0.71         6
#              Hardware - Purchase for Videoconference devices       0.00      0.00      0.00         1
#                         Health and Safety - Site Supervision       0.00      0.00      0.00         3
#                                         Health and Safety GP       0.79      0.70      0.75       193
#                                                      Heaters       0.25      0.30      0.27        10
#                                             Hostess services       0.83      0.94      0.88       148
#                                          Hotel accommodation       0.69      0.68      0.68        37
#                                          IT Service Desk T&M       0.00      0.00      0.00        21
#                          ITL - Altre spese di rappresentanza       0.00      0.00      0.00         0
#                                ITL - Spese di rappresentanza       1.00      0.33      0.50         3
#                           In-Pack Gadgets_Commercial Co-Pack       0.96      0.66      0.78        35
#                           In-Pack Gadgets_Industrial co-pack       0.72      0.63      0.67        46
#            In/Out Functional Display Production - Customized       0.53      0.55      0.54        47
#              In/Out Functional Display Production - Standard       0.86      0.60      0.71       482
#          In/Out Theatrical Materials Production - Customized       0.54      0.64      0.59        70
#            In/Out Theatrical Materials Production - Standard       0.94      0.71      0.80       143
#                                   Industrial 100x120 Pallets       0.00      0.00      0.00         0
#                                          Industrial Cleaning       0.77      0.84      0.80        55
#                                                    Infirmary       0.08      0.25      0.12         4
#                                   Influencers & Testimonials       0.73      0.76      0.75        25
#                                       Institutional Expenses       0.00      0.00      0.00        14
#                              Integrated Facility Maintenance       0.09      0.20      0.12        10
#                                                 Job postings       0.12      0.75      0.21        12
#                                                   Laboratory       0.24      0.67      0.35        96
#                                             Laundry Services       0.30      0.43      0.35         7
#                                               Legal Advisory       0.92      1.00      0.96        66
#                                               Legal services       1.00      0.67      0.80         6
#                                                       Levers       0.50      0.33      0.40         3
#                                        Liability (Insurance)       0.00      0.00      0.00         4
#                         Licensing - Brands & Content DIGITAL       0.14      0.18      0.16        17
#                     Licensing - Brands & Content TRADITIONAL       0.62      0.71      0.67        49
#                                    Licensing - Music DIGITAL       0.61      0.69      0.65        62
#                                Licensing - Music TRADITIONAL       0.00      0.00      0.00         4
#                                                     Lighting       0.06      0.80      0.11        10
#                                    Local Small Building rent       0.00      0.00      0.00         1
#                                               Locks, Handles       0.20      0.12      0.15        17
#                                         Long Stay Relocation       0.47      0.75      0.58        12
#                                      Long stay accommodation       0.29      0.25      0.27        16
#                                                   Lubricants       0.76      0.90      0.83        63
#                                    M&A related consultancies       0.00      0.00      0.00         9
#       Maintenace service not depreciable (Maintenance Order)       0.56      0.11      0.19       224
#            Maintenance And Services On Laboratory Equipments       0.21      0.50      0.29       115
#                             Maintenance Application Software       0.00      0.00      0.00         2
#                          Maintenance Server&Storage Software       0.00      0.00      0.00         1
#                  Maintenance Voice and Data Network Software       0.00      0.00      0.00         0
#                                     Manned guarding services       0.85      0.95      0.90       109
#                      Measure devices and Control instruments       0.06      0.11      0.07        27
#                                       Mechanical maintenance       0.82      0.26      0.39       465
#                    Media Relations, Membership & Partnership       0.00      0.00      0.00         2
#                                             Medical Services       0.85      0.86      0.85       148
#                                       Merchandising services       0.86      0.79      0.82       137
#                                               NGO, Donations       0.17      0.09      0.12        11
#                                   No Commercial Sponsorships       0.22      0.50      0.31         4
#         Not cod - PPE, Safety Work Products, Fire Protection       0.14      0.23      0.17       715
#              Not codified - Clothes & Uniforms, Safety Shoes       0.04      0.02      0.02       188
#               OPX - Agri Mobile Machine (Tractor, Harvester)       1.00      0.50      0.67         4
#                              OPX - Extraordinary Maintenance       0.86      0.40      0.54        48
#                           OPX - Forklifts (Rental & Service)       0.97      0.95      0.96      1301
#                                   OPX - Ordinary Maintenance       0.84      0.78      0.81      1518
#             OPX - Retrofit/revamping of an equipment or line       0.15      0.15      0.15        13
#                      OPX - Software, Licence Fee, Assistance       0.44      0.83      0.57        58
#                                         OTHER LOGISTIC COSTS       1.00      1.00      1.00         2
#                                         OTHER SALE DISCOUNTS       0.00      0.00      0.00         0
#                                     Office Furniture - Capex       0.39      0.90      0.54       382
#                     Office machines & equipment - Investment       0.87      0.86      0.86        56
#                    Office machines & equipment - Maintenance       0.61      0.56      0.59        48
#                                              Office supplies       0.80      0.81      0.80      4053
#                                 Optional insurance employees       1.00      1.00      1.00         1
#               Other Consumables, Material and Small Supplies       0.87      0.39      0.54      2035
#          Other Materials Immediate Use for Maintenance Plant       0.57      0.48      0.52      1691
#      Other Materials Immediate Use for Production Assistance       0.01      0.02      0.02        44
#           Other Spare parts (not codified, catalogues items)       0.64      0.39      0.49      2958
#                                               Other auditing       1.00      0.07      0.13        42
#   Other research activities on consumer, shopper and citizen       0.76      0.35      0.48        46
#          Other syndicated subscriptions (excluding RMS, CPS)       0.50      0.81      0.62        21
#                                        Other travel services       0.75      0.83      0.79        18
#                 Outsourcing of administrative services (bpo)       0.33      1.00      0.50         2
#                                                      PALLETS       1.00      1.00      1.00         1
#                                             PAYROLL SERVICES       1.00      1.00      1.00        73
#                            PHOTOCELLS AND PROXIMITY SWITCHES       0.43      0.73      0.54        45
#                          POS material Development & Sampling       0.43      0.91      0.58       130
#                 POS material Molds, Toolings, Die Cuts CAPEX       0.00      0.00      0.00         6
#                           POS materials Storage and Logistic       0.87      0.62      0.73       288
#       PR Communication Strategy, Advisory, Issues Management       1.00      0.13      0.24        75
#                                PR Digital Activities & Tools       0.19      1.00      0.31        18
#                                         PRINTERS CONSUMABLES       0.62      0.73      0.67        22
#                                         PRINTERS SPARE PARTS       0.63      0.48      0.55        25
#                                             PRODUCTION TOOLS       0.44      0.26      0.32        74
#                                            PROM.MAT.CASHDESK       0.00      0.00      0.00         0
#                                             PROMO POS MODERN       0.00      0.00      0.00         0
#                                             PROMO POS TRADNL       0.00      0.00      0.00         0
#                                    PROMOTIONAL POINT OF SALE       0.45      0.71      0.55       164
#  Packaging & POS - Artwork, Technical finalization&Templates       0.13      0.77      0.23       115
#                           Packaging & POS - Creative Concept       0.83      0.70      0.76      7186
#                          Packaging & POS - Mockups / Samples       0.37      0.19      0.25      2041
#                                                        Paint       0.30      0.43      0.35        14
#                                         Panel SPE management       0.67      0.67      0.67         6
#                                     People Security Services       0.50      0.30      0.37        20
#         Permanent Materials Production - Secondary Placement       0.84      0.86      0.85        56
#                                           Personal Insurance       1.00      0.50      0.67         2
#                                                 Pest Control       0.70      0.80      0.75       109
#                           Physical and Supply Chain security       1.00      0.55      0.71        11
#                                      Picking Finish Products       0.00      0.00      0.00         8
#                                             Picking Services       0.11      1.00      0.20         1
#                Plant Utilities EaaS (Equipment as a Service)       0.06      0.42      0.10        12
#                                Porter and reception services       0.83      0.62      0.71         8
#               Post-Production of Advertising Content DIGITAL       0.35      0.37      0.36       109
#           Post-Production of Advertising Content TRADITIONAL       0.70      0.73      0.71       418
#                                      Postage & Couriers Fees       0.31      0.74      0.44       110
#                                            Printing Supplies       0.67      0.77      0.72       213
#               Printing, photography and videomaking services       0.05      0.33      0.09        24
#                    Process Engineering professional services       0.34      0.66      0.45        59
#                    Production of Advertising Content DIGITAL       0.61      0.73      0.67       360
#        Production of Advertising Content TRADITIONAL - Radio       0.56      0.62      0.59       109
#          Production of Advertising Content TRADITIONAL - TVC       0.59      0.60      0.59        57
#     Production of Advertising Content TRADITIONAL-OOH,Static       0.76      0.38      0.51       237
#              Promotional items (including consumer giveaway)       1.00      0.98      0.99        87
#                       Property Cost Estimation & Acquisition       0.75      1.00      0.86         3
#                                         Property acquisition       0.08      1.00      0.14         4
#                                        Public relation costs       0.88      0.88      0.88        93
#                                                      Pulleys       0.27      0.75      0.40         4
#                                                        Pumps       0.26      0.71      0.37        17
#                               Purchase Applications Licenses       0.67      0.67      0.67         3
#                                 Purchase of product sampling       1.00      0.29      0.44         7
#                                                  RECRUITMENT       0.97      0.92      0.94        99
#                                     Real Estate Office Lease       0.95      0.43      0.59       134
#                      Real Estate Short-Term Lease <12 Months       0.79      0.90      0.84        21
#                                     Real estate Retail lease       1.00      1.00      1.00         6
#          Real estate others (no industrial, no supply chain)       1.00      0.33      0.50         3
#                                Recreation employees benefits       0.88      0.69      0.77        71
#                                   Rental 1/2 Plastic Pallets       1.00      1.00      1.00         1
#                                   Rental 1/4 Plastic Pallets       0.96      0.98      0.97        51
#                                        Rental 80x120 Pallets       0.00      0.00      0.00         1
#                            Rental Industrial 100x120 Pallets       0.00      0.00      0.00         1
#                                          Rental Services Fee       0.19      0.45      0.26        11
#                                  Research & Development cost       0.28      0.26      0.27        19
#    Research activities for qualifying Innovation initiatives       0.63      0.73      0.68        59
#    Research activities to assess the ADV/Communication Perf.       0.69      0.72      0.70        79
#         Researches to understand Consumers, Shopper, Markets       0.50      0.60      0.55        53
#                                       Retail Data monitoring       0.86      1.00      0.92        48
#                                             Retail Panels DB       0.91      0.96      0.94       123
# Rights buyout-Authors,Artists,Performers,Personality DIGITAL       0.30      0.54      0.39        48
#   Rights buyout-Authors,Artists,Performers,Personality TRADI       0.76      0.53      0.63       165
#                                                  Rigid pipes       0.12      0.33      0.18        24
#                                         Road Finish Products       0.00      0.00      0.00        12
#                                               Road Packaging       1.00      1.00      1.00         4
#                                          Road Transportation       0.50      0.46      0.48        28
#           Road Transportation Finished Products Export Costs       1.00      1.00      1.00         1
#                                                      Rollers       0.08      0.40      0.14         5
#                                                      SEO/SEM       0.00      0.00      0.00         9
#                                   SPARE PARTS FOR GAS PLANTS       0.33      0.12      0.18         8
#                                  SPECIFIC DRAWING COMPONENTS       0.27      0.52      0.35        42
#                                              SPROCKET WHEELS       0.03      0.67      0.05         3
#                                             SUNDRY INSURANCE       0.00      0.00      0.00         1
#                                              Safety supplies       0.46      0.82      0.59        40
#                                         Sales and B2B Events       0.50      0.11      0.18         9
#                                  School & Kinder garden fees       0.43      0.67      0.52        18
#                                                       Screws       0.21      0.80      0.33        25
#                                          Sea Finish Products       1.00      0.19      0.32        32
#                                            Sea RAW MATERIALS       0.00      0.00      0.00         0
#                         Sea Transportation Export Fees Costs       0.06      1.00      0.12         1
#                                          Security technology       0.75      0.79      0.77        58
#                                   Server&Storage Outsourcing       0.00      0.00      0.00         0
#                                           Server&Storage T&M       0.00      0.00      0.00         0
#                                     Server&Storage T&M CAPEX       0.00      0.00      0.00         0
#                                              Services Gadget       0.40      0.86      0.55         7
# Services for fridge and other tech devices for Point of Sale       0.30      0.33      0.32         9
#                                             Site supervision       0.16      0.29      0.21        28
#                                      Social Media Management       0.79      0.78      0.79       286
#                                      Spare Parts - Conveyors       0.17      0.44      0.25        25
#                                        Spare Parts Utilities       0.01      0.01      0.01        79
#                                             Spare parts kits       0.03      0.14      0.05         7
#      Specific Material For Utilities Machinery And Equipment       0.50      0.60      0.55        25
#                                                      Springs       0.27      0.80      0.40         5
#                                      Standard certifications       1.00      0.38      0.56        26
#                                      Storage Finish Products       1.00      0.67      0.80         3
#                                                  Storage Mtl       0.86      0.75      0.80         8
#                                        Storage RAW MATERIALS       0.50      1.00      0.67         2
#            Strategic, Managerial & organizational consulting       0.19      0.38      0.25        21
#                   Subscription Voice and Data Network (IaaS)       0.00      0.00      0.00         1
#           Subscriptions on Market measurement (license fees)       0.87      0.93      0.90        14
#                Subscriptions on Retail panels (license fees)       0.25      0.67      0.36         3
#                                                 Suction cups       0.75      0.75      0.75        20
#                        Surprises - Creative Concepts DIGITAL       0.12      0.02      0.04        88
#                    Surprises - Creative Concepts TRADITIONAL       0.14      0.66      0.24       375
#                                 Surprises - Marketing Sheets       0.63      0.32      0.43       737
#                            Surprises - Technical Development       0.30      0.73      0.42       433
#                                           TICKETS RESTAURANT       0.92      0.73      0.81        60
#                             TR - Archiving Services (GenAdm)       1.00      1.00      1.00         3
#                           TR - Building Maintenance (GenAdm)       0.00      0.00      0.00         0
#                               TR - Canteen Services (GenAdm)       0.84      0.86      0.85        37
#                              TR - Canteen Services (GenProd)       0.77      0.74      0.76        23
#                              TR - Cleaning services (GenAdm)       0.91      1.00      0.95        10
#                             TR - Cleaning services (GenProd)       1.00      0.86      0.92         7
#                                    TR - ELECTRICITY (GENADM)       1.00      1.00      1.00         3
#                                   TR - ELECTRICITY (GENPROD)       1.00      1.00      1.00         8
#             TR - Ground and green areas maintenance (GenAdm)       1.00      1.00      1.00        81
#                              TR - Handyman services (GenAdm)       1.00      0.75      0.86         4
#                             TR - Health and Safety (GenProd)       1.00      1.00      1.00         2
#                                TR - Office supplies (GenAdm)       1.00      0.89      0.94         9
#                               TR - Office supplies (GenProd)       0.80      1.00      0.89         4
#                                TR - People Security (GenAdm)       1.00      1.00      1.00         3
#                        TR - Postage & Couriers Fees (GenAdm)       0.78      1.00      0.88         7
#                       TR - Postage & Couriers Fees (GenProd)       0.00      0.00      0.00         2
#                       TR - Real Estate Office Lease (GenAdm)       1.00      1.00      1.00        14
#                         TR - Small Furniture - Opex (GenAdm)       1.00      1.00      1.00         1
#                        TR - Small Furniture - Opex (GenProd)       0.00      0.00      0.00         1
#                                       TR - Tolls and parking       0.96      1.00      0.98        25
#                   TR - Training costs of personnel (GenProd)       1.00      1.00      1.00        10
#                                          TR - WATER (GENADM)       1.00      1.00      1.00         2
#                                         TR - WATER (GENPROD)       1.00      1.00      1.00         2
#  TR-Specific Mtl For Warehouse, Lift And Handl. Equip.(S-Wh)       0.41      0.44      0.42        41
#                                  Tax & Customs Services Cost       0.00      0.00      0.00         4
#                                  Technical Cleaning material       0.85      0.80      0.82      1435
#              Technical Consultancy And External Lab Analysis       0.85      0.58      0.69       232
# Technical certifications, engineering-related consulting(TS)       0.11      0.42      0.17        19
#                                         Temporary Personnels       1.00      0.92      0.96       223
#                                           Testimonials Costs       0.76      1.00      0.86        16
#                           Training Design & Cost of Personal       1.00      0.96      0.98      2524
#                       Translations and interpreting services       0.78      0.58      0.67        31
#                                          Transport Surprises       0.00      0.00      0.00         0
#                                     Transportation - Flights       0.57      0.33      0.42        12
#                                       Transportation - Other       0.71      0.91      0.80        78
#                      Transportation - Short-term Rental Cars       0.96      0.88      0.92       214
#                              Travel Agencies fees & services       0.73      0.74      0.74       160
#                      Utilities - Electric Energy for Offices       0.88      0.88      0.88         8
#                                       Utilities - Office Gas       0.67      1.00      0.80         2
#                                     Utilities - Office Water       1.00      0.75      0.86         4
#                                                       Valves       0.35      0.60      0.44        58
#                                                    Vibrators       0.02      0.33      0.03         3
#            Voice and Data Network Communications Outsourcing       0.43      0.67      0.52         9
#                                               WORKSHOP TOOLS       0.18      0.77      0.30       225
#                                               Warehouse Rent       0.00      0.00      0.00         1
#      Warehouse Rental Other Costs (cleaning, security, etc…)       0.00      0.00      0.00         0
#                     Waste Management for industrial location       0.16      0.69      0.26        52
#                               Waste Water Treatment Services       0.08      0.02      0.03        46
#             Waste treatment, recycling and disposal services       0.95      0.77      0.85        71
#                                   Water for industrial plant       0.51      0.42      0.46        50
#                         Website / App Creation & Maintenance       0.88      0.68      0.77       311
#                                                       Wheels       0.20      0.67      0.31         6
# ...
#                                           SUND.LOCAL TX&DUTY       1.00      1.00      1.00        22
#                                             SUNDRY INSURANCE       0.98      0.91      0.95       138
#                                              Safety supplies       0.80      0.95      0.87       211
#                                         Sales and B2B Events       0.77      1.00      0.87        17
#                                  School & Kinder garden fees       0.42      1.00      0.59        47
#                                                       Screws       0.90      0.95      0.93      1089
#                                          Sea Finish Products       0.05      0.67      0.09        43
#                                   Sea Interm-Finished Prd-FI       0.41      0.86      0.56        14
#                                                Sea Packaging       0.37      0.95      0.53        19
#                                            Sea RAW MATERIALS       0.93      0.92      0.92       184
#                                      Sea SEMI-FINISHED GOODS       0.15      0.81      0.26        26
#                                                Sea Surprises       0.63      1.00      0.77       118
#                                           Sea Transportation       0.99      0.99      0.99       569
#                         Sea Transportation Export Fees Costs       0.82      0.50      0.62      1409
#                                          Security technology       0.97      0.97      0.97       120
#                                Server&Storage Licenses CAPEX       1.00      1.00      1.00         4
#                                   Server&Storage Outsourcing       1.00      0.93      0.97        30
#                                           Server&Storage T&M       0.88      0.88      0.88        16
#                                     Server&Storage T&M CAPEX       0.82      1.00      0.90         9
#                                              Services Gadget       1.00      1.00      1.00        10
#                               Services for credit collection       0.60      1.00      0.75         6
# Services for fridge and other tech devices for Point of Sale       0.93      0.98      0.95        41
#                                             Site supervision       0.94      1.00      0.97        17
#                                      Social Media Management       0.98      0.99      0.99       320
#                                      Spare Parts - Conveyors       0.97      0.93      0.95      1560
#                                        Spare Parts Utilities       0.94      0.95      0.94       455
#                                             Spare parts kits       0.91      0.88      0.90       767
#                             Special Projects Finish Products       1.00      1.00      1.00         1
#      Specific Material For Utilities Machinery And Equipment       0.20      1.00      0.34        19
#                                                      Springs       0.92      0.92      0.92       332
#                                      Standard certifications       0.93      1.00      0.96        27
#                                      Storage Finish Products       0.32      0.95      0.48        37
#                       Storage Finished Products (co-packing)       0.97      0.97      0.97        38
#                               Storage Interm-Finished Prd-FI       1.00      1.00      1.00        77
#                                                  Storage Mtl       0.87      0.91      0.89       420
#                                            Storage Packaging       0.92      0.57      0.70       121
#                                        Storage RAW MATERIALS       0.87      0.81      0.84        83
#                                  Storage SEMI-FINISHED GOODS       0.03      1.00      0.05         5
#                                            Storage Surprises       0.77      0.42      0.55       266
#            Strategic, Managerial & organizational consulting       0.90      0.97      0.93       116
#                       Subscription End-User Computing (SaaS)       0.96      0.92      0.94        26
#                   Subscription Voice and Data Network (IaaS)       0.79      1.00      0.88        23
#           Subscriptions on Market measurement (license fees)       0.92      0.91      0.91       191
#                Subscriptions on Retail panels (license fees)       0.88      1.00      0.94        15
#                                                 Suction cups       0.92      0.95      0.94       432
#                        Surprises - Creative Concepts DIGITAL       1.00      1.00      1.00         4
#                    Surprises - Creative Concepts TRADITIONAL       0.50      1.00      0.67        11
#                                 Surprises - Marketing Sheets       1.00      0.71      0.83        21
#                            Surprises - Technical Development       0.88      1.00      0.94        15
#                                      Surprises certification       0.91      0.97      0.94        30
#                                           TICKETS RESTAURANT       0.90      0.92      0.91       118
#                TR - Accessories technology supplies (GenAdm)       1.00      1.00      1.00         1
#               TR - Accessories technology supplies (GenProd)       1.00      1.00      1.00         1
#                             TR - Archiving Services (GenAdm)       1.00      1.00      1.00        21
#                           TR - Building Maintenance (GenAdm)       1.00      0.95      0.97        20
#                               TR - Canteen Services (GenAdm)       1.00      0.98      0.99       163
#                              TR - Canteen Services (GenProd)       0.95      1.00      0.97        95
#                              TR - Cleaning services (GenAdm)       0.96      0.99      0.98        81
#                             TR - Cleaning services (GenProd)       0.95      0.96      0.95        74
#         TR - Company Vehicles - Fuel, Oil and other (GenAdm)       0.87      0.89      0.88        44
#        TR - Company Vehicles - Fuel, Oil and other (GenProd)       0.63      0.93      0.75        29
#                       TR - Company Vehicles - Lease (GenAdm)       0.97      0.82      0.89        34
#                      TR - Company Vehicles - Lease (GenProd)       0.56      0.71      0.63         7
#                         TR - Company Vehicles - Lease (S-Wh)       0.62      1.00      0.77         5
#          TR - Company Vehicles - Maintenance costs (GenProd)       1.00      1.00      1.00         1
#                         TR - Donations to employees (GenAdm)       1.00      1.00      1.00         4
#                                    TR - ELECTRICITY (GENADM)       1.00      1.00      1.00        12
#                                   TR - ELECTRICITY (GENPROD)       0.97      1.00      0.99        34
#                   TR - Employees Transport Services (GenAdm)       1.00      0.97      0.99        40
#                  TR - Employees Transport Services (GenProd)       0.98      1.00      0.99        61
#     TR - Employees event and social activities cost (GenAdm)       0.93      1.00      0.97        14
#    TR - Employees event and social activities cost (GenProd)       1.00      1.00      1.00         2
#                    TR - Expenses for notary charges (GenAdm)       1.00      1.00      1.00         3
#                                           TR - GAS (GENPROD)       1.00      1.00      1.00         6
#             TR - Ground and green areas maintenance (GenAdm)       0.27      1.00      0.43         6
#            TR - Ground and green areas maintenance (GenProd)       1.00      1.00      1.00         4
#                               TR - HR&OI Consulting (GenAdm)       1.00      1.00      1.00         6
#                              TR - Handyman services (GenAdm)       1.00      1.00      1.00        16
#                              TR - Health and Safety (GenAdm)       0.61      1.00      0.76        17
#                             TR - Health and Safety (GenProd)       0.93      0.97      0.95        71
#        TR - IA & Corporate Communication consulting (GenAdm)       1.00      1.00      1.00         2
#                               TR - Legal consulting (GenAdm)       1.00      1.00      1.00        33
#                                TR - Office supplies (GenAdm)       0.96      0.98      0.97        53
#                               TR - Office supplies (GenProd)       1.00      1.00      1.00        16
#                 TR - Opx Voice, Data Network-Transms(GenAdm)       0.97      0.95      0.96        38
#                          TR - Other Fuel Exp - no deductible       0.67      1.00      0.80         2
#                      TR - PURCHASE DISTRICT HEATING (GENADM)       0.72      1.00      0.84        18
#                                TR - People Security (GenAdm)       1.00      1.00      1.00         5
#                             TR - Personal insurance (GenAdm)       1.00      1.00      1.00         2
#                         TR - Pest Control services (GenProd)       1.00      0.96      0.98        24
#                        TR - Postage & Couriers Fees (GenAdm)       1.00      0.95      0.98        22
#                       TR - Postage & Couriers Fees (GenProd)       0.29      1.00      0.44        14
#                             TR - Printing Supplies (GenProd)       1.00      1.00      1.00         2
#                       TR - Real Estate Office Lease (GenAdm)       1.00      0.90      0.95        59
#                                TR - Safety supplies (GenAdm)       1.00      1.00      1.00         2
#                            TR - Security technology (GenAdm)       0.75      1.00      0.86         3
#                         TR - Small Furniture - Opex (GenAdm)       1.00      1.00      1.00         2
#                        TR - Small Furniture - Opex (GenProd)       1.00      1.00      1.00         2
#                               TR - Sundry insurance (GenAdm)       1.00      1.00      1.00         1
#  TR - Technical Consulting non-Industrial Buildings (GenAdm)       0.75      1.00      0.86         6
#                            TR - Temporary personnel (GenAdm)       1.00      1.00      1.00         1
#                           TR - Temporary personnel (GenProd)       1.00      1.00      1.00         2
#                                       TR - Tolls and parking       0.96      0.93      0.95        74
#                    TR - Training costs of personnel (GenAdm)       0.93      0.96      0.95        27
#                   TR - Training costs of personnel (GenProd)       0.85      1.00      0.92        22
#         TR - Translations and interpreting services (GenAdm)       1.00      0.92      0.96        13
#                TR - Travel Agencies fees & services (GenAdm)       1.00      1.00      1.00         5
#               TR - Travel Agencies fees & services (GenProd)       1.00      1.00      1.00         2
#                                          TR - WATER (GENADM)       1.00      0.94      0.97        16
#                                         TR - WATER (GENPROD)       1.00      1.00      1.00        31
# TR - Waste treatment, recycling and disposal services (S-Wh)       1.00      1.00      1.00         2
#  TR-Specific Mtl For Warehouse, Lift And Handl. Equip.(S-Wh)       0.82      1.00      0.90        18
# TR-Waste treatment,recycling and disposal services (GenProd)       1.00      1.00      1.00         3
#                                  Tax & Customs Services Cost       1.00      1.00      1.00         7
#                                  Technical Cleaning material       0.94      0.91      0.92      1588
#              Technical Consultancy And External Lab Analysis       0.96      0.90      0.93       291
# Technical certifications, engineering-related consulting(TS)       0.74      0.97      0.84       113
#                                         Temporary Personnels       0.94      0.90      0.92       383
#                                           Testimonials Costs       0.97      1.00      0.98        30
#                           Training Design & Cost of Personal       0.87      0.91      0.89       120
#                       Translations and interpreting services       0.89      0.93      0.91        84
#                              Transport Intermediate Products       0.08      0.30      0.13       314
#                                          Transport Packaging       0.06      1.00      0.12         1
#                                      Transport Raw Materials       0.08      0.50      0.14         2
#                                      Transport Semi Finished       0.26      0.63      0.37       295
#                                          Transport Surprises       0.03      0.95      0.05        19
#                                     Transportation - Flights       0.91      1.00      0.95        10
#                                       Transportation - Other       0.69      0.97      0.81        77
#                      Transportation - Short-term Rental Cars       0.97      0.93      0.95       273
#                              Travel Agencies fees & services       0.96      0.88      0.92       326
#                                             Travel insurance       1.00      1.00      1.00         1
#                      Utilities - Electric Energy for Offices       0.84      0.91      0.87       100
#                                       Utilities - Office Gas       0.32      1.00      0.49        19
#                                     Utilities - Office Water       0.95      1.00      0.97        39
#                                                       Valves       0.92      0.90      0.91      1529
#                                                    Vibrators       0.19      0.94      0.31        47
#            Voice and Data Network Communications Outsourcing       1.00      0.88      0.93       244
#                        Voice and Data Network Licenses CAPEX       1.00      1.00      1.00         2
#                           Voice and Data Network Outsourcing       0.74      0.96      0.84        27
#                                   Voice and Data Network T&M       0.58      0.94      0.71        16
#                                              WAREHOUSE LEASE       0.98      1.00      0.99        56
#                                               WORKSHOP TOOLS       0.97      0.94      0.96      2899
#                                               Warehouse Rent       0.96      1.00      0.98        27
#      Warehouse Rental Other Costs (cleaning, security, etc…)       1.00      1.00      1.00         6
#                                         Waste Management Svc       0.79      0.85      0.81        13
#                     Waste Management for industrial location       0.72      0.95      0.82        82
#                               Waste Water Treatment Services       1.00      0.91      0.95        11
#             Waste treatment, recycling and disposal services       0.97      0.94      0.95       325
#                                   Water for industrial plant       0.43      0.98      0.60        49
#                                        Web domain management       1.00      1.00      1.00         2
#                         Website / App Creation & Maintenance       0.97      0.96      0.96       284
#                                                       Wheels       0.59      0.93      0.72       163
#                                                 Сonstruction       0.88      0.94      0.91       613
#
#                                                     accuracy                           0.88    311220
#                                                    macro avg       0.82      0.94      0.86    311220
#                                                 weighted avg       0.91      0.88      0.89    311220

# %%
#model(
#    GradientBoostingClassifier, X_tr=X_train3, y_tr=y_train3, X_ts=X_test3, y_ts=y_test3, gradient_boosting=True, n_ests=100, lr=0.01
#)
